# %%
import lightkurve as lk
print("Lightkurve version:", lk.__version__)
# Out:
# Lightkurve version: 2.6.0
# C:\Users\giahy\Downloads\anaconda\Lib\site-packages\lightkurve\prf\__init__.py:7: UserWarning: Warning: the tpfmodel submodule is not available without oktopus installed, which requires a current version of autograd. See #1452 for details.
#   warnings.warn(

# %%
search_result = lk.search_targetpixelfile("Kepler-10", mission="Kepler")
print(search_result)
# Out:
# SearchResult containing 49 data products.
#
#  #       mission      year author exptime  target_name  distance
#                                      s                   arcsec
# --- ----------------- ---- ------ ------- ------------- --------
#   0 Kepler Quarter 02 2009 Kepler      60 kplr011904151      0.0
#   1 Kepler Quarter 03 2009 Kepler      60 kplr011904151      0.0
#   2 Kepler Quarter 03 2009 Kepler      60 kplr011904151      0.0
#   3 Kepler Quarter 03 2009 Kepler      60 kplr011904151      0.0
#   4 Kepler Quarter 00 2009 Kepler    1800 kplr011904151      0.0
#   5 Kepler Quarter 01 2009 Kepler    1800 kplr011904151      0.0
#   6 Kepler Quarter 02 2009 Kepler    1800 kplr011904151      0.0
#   7 Kepler Quarter 03 2009 Kepler    1800 kplr011904151      0.0
#   8 Kepler Quarter 04 2010 Kepler      60 kplr011904151      0.0
#   9 Kepler Quarter 05 2010 Kepler      60 kplr011904151      0.0
#  10 Kepler Quarter 05 2010 Kepler      60 kplr011904151      0.0
#  11 Kepler Quarter 05 2010 Kepler      60 kplr011904151      0.0
#  12 Kepler Quarter 06 2010 Kepler      60 kplr011904151      0.0
#  13 Kepler Quarter 06 2010 Kepler      60 kplr011904151      0.0
#  14 Kepler Quarter 06 2010 Kepler      60 kplr011904151      0.0
#  15 Kepler Quarter 07 2010 Kepler      60 kplr011904151      0.0
#  16 Kepler Quarter 07 2010 Kepler      60 kplr011904151      0.0
#  17 Kepler Quarter 07 2010 Kepler      60 kplr011904151      0.0
#  18 Kepler Quarter 04 2010 Kepler    1800 kplr011904151      0.0
#  19 Kepler Quarter 05 2010 Kepler    1800 kplr011904151      0.0
#  20 Kepler Quarter 06 2010 Kepler    1800 kplr011904151      0.0
#  21 Kepler Quarter 07 2010 Kepler    1800 kplr011904151      0.0
#  22 Kepler Quarter 09 2011 Kepler      60 kplr011904151      0.0
#  23 Kepler Quarter 09 2011 Kepler      60 kplr011904151      0.0
#  24 Kepler Quarter 09 2011 Kepler      60 kplr011904151      0.0
#  25 Kepler Quarter 10 2011 Kepler      60 kplr011904151      0.0
#  26 Kepler Quarter 10 2011 Kepler      60 kplr011904151      0.0
#  27 Kepler Quarter 10 2011 Kepler      60 kplr011904151      0.0
#  28 Kepler Quarter 11 2011 Kepler      60 kplr011904151      0.0
#  29 Kepler Quarter 11 2011 Kepler      60 kplr011904151      0.0
#  30 Kepler Quarter 09 2011 Kepler    1800 kplr011904151      0.0
#  31 Kepler Quarter 10 2011 Kepler    1800 kplr011904151      0.0
#  32 Kepler Quarter 11 2012 Kepler      60 kplr011904151      0.0
#  33 Kepler Quarter 13 2012 Kepler      60 kplr011904151      0.0
#  34 Kepler Quarter 13 2012 Kepler      60 kplr011904151      0.0
#  35 Kepler Quarter 13 2012 Kepler      60 kplr011904151      0.0
#  36 Kepler Quarter 14 2012 Kepler      60 kplr011904151      0.0
#  37 Kepler Quarter 14 2012 Kepler      60 kplr011904151      0.0
#  38 Kepler Quarter 14 2012 Kepler      60 kplr011904151      0.0
#  39 Kepler Quarter 15 2012 Kepler      60 kplr011904151      0.0
#  40 Kepler Quarter 15 2012 Kepler      60 kplr011904151      0.0
#  41 Kepler Quarter 11 2012 Kepler    1800 kplr011904151      0.0
#  42 Kepler Quarter 13 2012 Kepler    1800 kplr011904151      0.0
#  43 Kepler Quarter 14 2012 Kepler    1800 kplr011904151      0.0
#  44 Kepler Quarter 15 2013 Kepler      60 kplr011904151      0.0
#  45 Kepler Quarter 17 2013 Kepler      60 kplr011904151      0.0
#  46 Kepler Quarter 17 2013 Kepler      60 kplr011904151      0.0
#  47 Kepler Quarter 15 2013 Kepler    1800 kplr011904151      0.0
#  48 Kepler Quarter 17 2013 Kepler    1800 kplr011904151      0.0
# C:\Users\giahy\Downloads\anaconda\Lib\site-packages\lightkurve\search.py:421: LightkurveWarning: Warning: 49 files available to download. Only the first file has been downloaded. Please use `download_all()` or specify additional criteria (e.g. quarter, campaign, or sector) to limit your search.
#   warnings.warn(
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\Downloads\anaconda\Lib\site-packages\lightkurve\io\read.py:98, in read(path_or_url, **kwargs)
#      97     with fits.open(path_or_url) as temp:
# ---> 98         filetype = detect_filetype(temp)
#      99 log.debug("Detected filetype: '{}'.".format(filetype))
#
# File ~\Downloads\anaconda\Lib\site-packages\lightkurve\io\detect.py:65, in detect_filetype(hdulist)
#      60 # Is it a PATHOS TESS light curve?
#      61 # cf. http://archive.stsci.edu/hlsp/pathos
#      62 # The 'pathos' name doesn't stay in the filename if when we use fits.open
#      63 # to download a file, so we have to check for all the important columns
#      64 # This will cause problems if another HLSP has the exact same colnames...
# ---> 65 if all(
#      66     x in hdulist[1].columns.names
#      67     for x in [
#      68         "PSF_FLUX_RAW",
#      69         "PSF_FLUX_COR",
#      70         "AP4_FLUX_RAW",
#      71         "AP4_FLUX_COR",
#      72         "SKY_LOCAL",
#      73     ]
#      74 ):
#      75     return "PATHOS"
#
# File ~\Downloads\anaconda\Lib\site-packages\lightkurve\io\detect.py:66, in <genexpr>(.0)
#      60 # Is it a PATHOS TESS light curve?
#      61 # cf. http://archive.stsci.edu/hlsp/pathos
#      62 # The 'pathos' name doesn't stay in the filename if when we use fits.open
#      63 # to download a file, so we have to check for all the important columns
#      64 # This will cause problems if another HLSP has the exact same colnames...
#      65 if all(
# ---> 66     x in hdulist[1].columns.names
#      67     for x in [
#      68         "PSF_FLUX_RAW",
#      69         "PSF_FLUX_COR",
#      70         "AP4_FLUX_RAW",
#      71         "AP4_FLUX_COR",
#      72         "SKY_LOCAL",
#      73     ]
#      74 ):
#      75     return "PATHOS"
#
# File ~\Downloads\anaconda\Lib\site-packages\astropy\io\fits\hdu\hdulist.py:393, in HDUList.__getitem__(self, key)
#     392 if self._read_all:
# --> 393     raise e
#     394 else:
#
# File ~\Downloads\anaconda\Lib\site-packages\astropy\io\fits\hdu\hdulist.py:387, in HDUList.__getitem__(self, key)
#     386 try:
# --> 387     return self._try_while_unread_hdus(
#     388         super().__getitem__, self._positive_index_of(key)
#     389     )
#     390 except IndexError as e:
#     391     # Raise a more helpful IndexError if the file was not fully read.
#
# File ~\Downloads\anaconda\Lib\site-packages\astropy\io\fits\hdu\hdulist.py:1287, in HDUList._try_while_unread_hdus(self, func, *args, **kwargs)
#    1286 try:
# -> 1287     return func(*args, **kwargs)
#    1288 except Exception:
#
# IndexError: list index out of range
#
# The above exception was the direct cause of the following exception:
#
# LightkurveError                           Traceback (most recent call last)
# Cell In[4], line 3
#       1 search_result = lk.search_targetpixelfile("Kepler-10", mission="Kepler")
#       2 print(search_result)
# ----> 3 lc = search_result.download()
#
# File ~\Downloads\anaconda\Lib\site-packages\lightkurve\utils.py:568, in suppress_stdout.<locals>.wrapper(*args, **kwargs)
#     566 sys.stdout = devnull
#     567 try:
# --> 568     return f(*args, **kwargs)
#     569 # restore to default
#     570 finally:
#     571     sys.stdout = old_out
#
# File ~\Downloads\anaconda\Lib\site-packages\lightkurve\search.py:430, in SearchResult.download(self, quality_bitmask, download_dir, cutout_size, **kwargs)
#     420 if len(self.table) != 1:
#     421     warnings.warn(
#     422         "Warning: {} files available to download. "
#     423         "Only the first file has been downloaded. "
#    (...)    427         LightkurveWarning,
#     428     )
# --> 430 return self._download_one(
#     431     table=self.table[:1],
#     432     quality_bitmask=quality_bitmask,
#     433     download_dir=download_dir,
#     434     cutout_size=cutout_size,
#     435     **kwargs,
#     436 )
#
# File ~\Downloads\anaconda\Lib\site-packages\lightkurve\search.py:361, in SearchResult._download_one(self, table, quality_bitmask, download_dir, cutout_size, **kwargs)
#     359     path = download_response["Local Path"]
#     360     log.debug("Finished downloading.")
# --> 361 return read(path, quality_bitmask=quality_bitmask, **kwargs)
#
# File ~\Downloads\anaconda\Lib\site-packages\lightkurve\io\read.py:107, in read(path_or_url, **kwargs)
#     104         raise e
#     105 except Exception as exc2:
#     106     # case unexpected error during detection, e.g., if a file is corrupted such that FITS headers are truncated
# --> 107     raise LightkurveError(
#     108         f"Unexpected error in detecting the type of the data product: '{type(exc2).__name__}: {exc2}'\n"
#     109         f"{path_or_url}\n"
#     110         "This file may be corrupt due to an interrupted download. "
#     111         "Please remove it from your disk and try again."
#     112     ) from exc2
#     114 try:
#     115     if filetype == "KeplerLightCurve":
#
# LightkurveError: Unexpected error in detecting the type of the data product: 'IndexError: list index out of range'
# C:\Users\giahy\.lightkurve\cache\mastDownload\Kepler\kplr011904151_sc_Q001313330333033302\kplr011904151-2009231120729_spd-targ.fits.gz
# This file may be corrupt due to an interrupted download. Please remove it from your disk and try again.

# %%
lc = search_result[0].download()
print(type(lc))
print(lc)

# %%
# %matplotlib inline
lc.plot(title="Kepler-10 Raw Light Curve")
