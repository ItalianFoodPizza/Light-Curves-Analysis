# %%
import lightkurve as lk
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import astroquery
import astropy
from astropy.table import Table
# Out:
# C:\Users\giahy\Downloads\anaconda\Lib\site-packages\lightkurve\prf\__init__.py:7: UserWarning: Warning: the tpfmodel submodule is not available without oktopus installed, which requires a current version of autograd. See #1452 for details.
#   warnings.warn(

# %%
from astroquery.ipac.nexsci.nasa_exoplanet_archive import NasaExoplanetArchive

#get table from nasa database
koi_table = NasaExoplanetArchive.query_criteria(
    table="koi",
    select="kepid, kepoi_name, koi_period, koi_disposition, koi_kepmag",
    where="koi_disposition like 'CANDIDATE' and koi_kepmag < 14"
)

#convert to dataframe
df = koi_table.to_pandas()
print(f"Found {len(df)} candidate stars")
print(df.head())
# Out:
# Found 3255 candidate stars
#       kepid kepoi_name  koi_period koi_disposition  koi_kepmag
# 0   9579641  K00115.03    3.435916       CANDIDATE      12.791
# 1  10460629  K01168.01  856.672115       CANDIDATE      13.997
# 2  10319385  K01169.01    0.689210       CANDIDATE      13.248
# 3  11502218  K00970.01    3.988602       CANDIDATE       6.974
# 4  11180361  K00971.01    0.533059       CANDIDATE       7.748

# %%
#sort and pick top 50 only
df_sorted = df.sort_values('koi_kepmag', ascending=True)
df_sample = df_sorted.head(50).reset_index(drop=True)

#print range and 10 first stars
print(f"Working sample: {len(df_sample)} stars")
print(f"Brightness range: {df_sample['koi_kepmag'].min():.1f} to {df_sample['koi_kepmag'].max():.1f}")
print(df_sample[['kepid', 'kepoi_name', 'koi_period', 'koi_kepmag']].head(10))
# Out:
# Working sample: 50 stars
# Brightness range: 7.0 to 10.1
#       kepid kepoi_name  koi_period  koi_kepmag
# 0  11502218  K00970.01    3.988602       6.974
# 1  11502218  K00970.01    3.988602       6.974
# 2  11180361  K00971.01    0.533059       7.748
# 3  11180361  K00971.01    0.533059       7.748
# 4  11180361  K00971.01    0.533059       7.748
# 5   5108214  K01924.01    2.119128       7.837
# 6   5108214  K01924.01    2.119130       7.837
# 7   4150611  K03156.04   94.224542       7.899
# 8   4150611  K03156.01    0.761122       7.899
# 9   4150611  K03156.01    0.761120       7.899

# %%
results = []

#go over every row and get that star's lightcurve
for idx, row in df_sample.iterrows():
    kepid = str(int(row['kepid']))
    print(f"Processing {idx+1}/50: KIC {kepid}...", end=" ")
    
    try:
        search = lk.search_lightcurve(
            f"KIC {kepid}", 
            mission="Kepler"
        )
        
        if len(search) == 0:
            print("No data found, skipping")
            continue
            
        lc = search[0].download()

        #clean and save period
        lc = lc.remove_nans().remove_outliers(sigma=3).normalize()
        
        pg = lc.to_periodogram(
            method="bls",
            period=np.arange(0.5, 30, 0.01)
        )

        best_period = pg.period_at_max_power.value
        best_power = pg.max_power.value

        #save to results list
        results.append({
            'kepid': kepid,
            'kepoi_name': row['kepoi_name'],
            'detected_period': round(best_period, 4),
            'catalog_period': round(row['koi_period'], 4),
            'bls_power': round(best_power, 4),
            'koi_kepmag': round(row['koi_kepmag'], 2),
            'data_points': len(lc)
        })
        
        print(f"Period: {best_period:.3f} days, Power: {best_power:.4f}")
        
    except Exception as e:
        print(f"Error: {e}, skipping")
        continue

print(f"\nPipeline complete. Processed {len(results)} stars successfully.")

results_df = pd.DataFrame(results)
print(results_df)
# Out:
#
# 49   3848948  K05016.01             0.80          0.5236  1.757909e+02
#
#     koi_kepmag  data_points
# 0         6.97         1605
# 1         6.97         1605
# 2         7.75        37468
# 3         7.75        37468
# 4         7.75        37468
# 5         7.84          467
# 6         7.84          467
# 7         7.90        41767
# 8         7.90        41767
# 9         7.90        41767
# 10        8.65        43975
# 11        8.65        43975
# 12        8.65        43975
# 13        8.78        49032
# 14        8.79        49032
# 15        9.00        47891
# 16        9.28        41808
# 17        9.28        41808
# 18        9.28        41808
# 19        9.28        41758
# 20        9.28        41758
# 21        9.28        41758
# 22        9.58          436
# 23        9.58          436
# 24        9.58        41681
# 25        9.58        41681
# 26        9.58        41681
# 27        9.58        41681
# 28        9.58        41681
# 29        9.58        41681
# 30        9.58        41681
# 31        9.71          466
# 32        9.71          466
# 33        9.73          469
# 34        9.73          469
# 35        9.73          469
# 36        9.73          469
# 37        9.75          469
# 38        9.75          469
# 39        9.75          469
# 40        9.84          469
# 41        9.84          469
# 42        9.89        38240
# 43        9.98        42771
# 44        9.98        42771
# 45        9.98        42771
# 46       10.03          464
# 47       10.03          464
# 48       10.03          464
# 49       10.06        14135

# %%
results_df = pd.DataFrame(results)

#calculate how close period is to NASA data
results_df['period_match'] = abs(
    results_df['detected_period'] - results_df['catalog_period']
) / results_df['catalog_period'] * 100

#round
results_df['period_match'] = results_df['period_match'].round(2)

# sort bls big to small
results_df_sorted = results_df.sort_values('bls_power', ascending=False)

print("TOP 10 CANDIDATES BY SIGNAL STRENGTH")
print("=" * 60)
print(results_df_sorted[['kepoi_name', 'detected_period', 
                           'catalog_period', 'bls_power', 
                           'period_match']].head(10).to_string())
# Out:
# TOP 10 CANDIDATES BY SIGNAL STRENGTH
# ============================================================
#    kepoi_name  detected_period  catalog_period     bls_power  period_match
# 13  K08061.01             2.24          0.7197  1.318546e+07        211.24
# 14  K05346.01            18.47         21.1273  1.316626e+07         12.58
# 23  K03161.01             1.56          6.0941  1.217742e+07         74.40
# 22  K03161.01             1.56          6.0941  1.217742e+07         74.40
# 7   K03156.04             1.43         94.2245  8.134426e+06         98.48
# 8   K03156.01             1.43          0.7611  8.134426e+06         87.89
# 9   K03156.01             1.43          0.7611  8.134426e+06         87.89
# 15  K06311.01             7.05          7.0471  1.063910e+06          0.04
# 2   K00971.01             0.53          0.5331  9.716629e+05          0.58
# 3   K00971.01             0.53          0.5331  9.716629e+05          0.58

# %%
results_clean = results_df_sorted.drop_duplicates(
    subset='kepid', keep='first'
).reset_index(drop=True)

top10 = results_clean.head(10)

fig, axes = plt.subplots(5, 2, figsize=(16, 20))
axes = axes.flatten()

fig.suptitle('Top 10 Exoplanet Candidates — Folded Light Curves', 
             fontsize=16, fontweight='bold', y=1.01)

for idx, row in top10.iterrows():
    kepid = str(int(row['kepid']))
    ax = axes[idx]
    
    try:
        search = lk.search_lightcurve(
            f"KIC {kepid}", 
            mission="Kepler", 
            cadence="long"
        )
        lc = search[0].download()
        lc = lc.remove_nans().remove_outliers(sigma=3).normalize()
        
        # Fold using detected period
        lc_folded = lc.fold(period=row['detected_period'])
        
        # Plot onto subplot
        lc_folded.scatter(ax=ax, s=1, alpha=0.5, color='steelblue')
        
        # Labels
        ax.set_title(
            f"{row['kepoi_name']} | Period: {row['detected_period']:.3f}d | "
            f"Match: {row['period_match']}%",
            fontsize=9
        )
        ax.set_xlabel("Phase", fontsize=8)
        ax.set_ylabel("Normalized Flux", fontsize=8)
        
        # Highlight the transit dip region
        ax.axvspan(-0.05, 0.05, alpha=0.15, color='red', 
                   label='Transit zone')
        
    except Exception as e:
        ax.text(0.5, 0.5, f"Error: {str(e)[:40]}", 
                transform=ax.transAxes, ha='center', fontsize=8)
        ax.set_title(f"{row['kepoi_name']} — data unavailable", fontsize=9)

plt.tight_layout()
plt.savefig('./outputs/v2_top10_folded.png', 
            dpi=150, bbox_inches='tight')
plt.show()
print("Plot saved to outputs/v2_top10_folded.png")
# Out:
# Plot saved to outputs/v2_top10_folded.png

# %%
# ── SECTION 10: AUTOMATIC CANDIDATE CLASSIFICATION ──────────

def classify_candidate(row):
    """
    Automatically classify each candidate based on measurable criteria.
    Returns classification label and reason.
    """
    period_match = row['period_match']
    bls_power = row['bls_power']
    detected_period = row['detected_period']
    catalog_period = row['catalog_period']
    
    # Rule 1: Period match > 150% — detected completely wrong period
    if period_match > 150:
        return 'FALSE POSITIVE', 'Period mismatch >150% — BLS detected unrelated signal'
    
    # Rule 2: Very long detected period relative to catalog
    # BLS likely found harmonic or alias
    if detected_period > catalog_period * 1.8:
        return 'FALSE POSITIVE', 'Detected period >> catalog — likely harmonic alias'
    
    # Rule 3: Very low BLS power — weak signal regardless of period match
    if bls_power < 0.002:
        return 'FALSE POSITIVE', 'BLS power too low — signal indistinguishable from noise'
    
    # Rule 4: Period match > 50% but reasonable power
    # Possibly real star but wrong period detected
    if period_match > 50:
        return 'WEAK', f'Period mismatch {period_match:.1f}% — partial signal only'
    
    # Rule 5: Period match 20-50% — moderate confidence
    if period_match > 20:
        return 'MODERATE', f'Period mismatch {period_match:.1f}% — possible detection'
    
    # Rule 6: Period match < 20% and good power — strong candidate
    if period_match <= 20 and bls_power >= 0.002:
        return 'STRONG', f'Period match {period_match:.1f}% with good BLS power'
    
    return 'UNCERTAIN', 'Does not meet any classification criteria clearly'


# Apply classifier to deduplicated top results
# First deduplicate — keep best BLS power per unique star
results_dedup = results_df.drop_duplicates(
    subset='kepid', keep='first'
).copy()

print(f"Total unique stars analyzed: {len(results_dedup)}")
print(f"Duplicates removed: {len(results_df) - len(results_dedup)}")

# Apply classification
results_dedup[['classification', 'reason']] = results_dedup.apply(
    lambda row: pd.Series(classify_candidate(row)), axis=1
)

# Print full classification table
print("\nFULL CLASSIFICATION TABLE")
print("=" * 80)
print(results_dedup[['kepoi_name', 'detected_period', 'catalog_period', 
                       'period_match', 'bls_power', 
                       'classification', 'reason']].to_string())

print("\nCLASSIFICATION SUMMARY")
print("=" * 60)

# Count each classification
summary = results_dedup['classification'].value_counts()
total = len(results_dedup)

for label, count in summary.items():
    pct = count / total * 100
    print(f"  {label:<20} {count:>3} candidates ({pct:.1f}%)")

print(f"\n  TOTAL                {total:>3} unique stars")

# False positive rate
fp_count = summary.get('FALSE POSITIVE', 0)
fp_rate = fp_count / total * 100
print(f"\nFalse positive rate:  {fp_rate:.1f}%")
print(f"Detection rate:       {(total - fp_count) / total * 100:.1f}%")

results_dedup.to_csv('./outputs/v2_candidates_classified.csv', index=False)
print("Saved classified results to outputs/v2_candidates_classified.csv")
# Out:
# Total unique stars analyzed: 20
# Duplicates removed: 30
#
# FULL CLASSIFICATION TABLE
# ================================================================================
#    kepoi_name  detected_period  catalog_period  period_match     bls_power  classification                                                 reason
# 0   K00970.01            13.69          3.9886        243.23  4.643799e+05  FALSE POSITIVE  Period mismatch >150% — BLS detected unrelated signal
# 2   K00971.01             0.53          0.5331          0.58  9.716629e+05          STRONG                  Period match 0.6% with good BLS power
# 5   K01924.01             2.10          2.1191          0.90  2.186702e+03          STRONG                  Period match 0.9% with good BLS power
# 7   K03156.04             1.43         94.2245         98.48  8.134426e+06            WEAK            Period mismatch 98.5% — partial signal only
# 10  K06141.01             0.94         96.5092         99.03  1.175941e+05            WEAK            Period mismatch 99.0% — partial signal only
# 13  K08061.01             2.24          0.7197        211.24  1.318546e+07  FALSE POSITIVE  Period mismatch >150% — BLS detected unrelated signal
# 14  K05346.01            18.47         21.1273         12.58  1.316626e+07          STRONG                 Period match 12.6% with good BLS power
# 15  K06311.01             7.05          7.0471          0.04  1.063910e+06          STRONG                  Period match 0.0% with good BLS power
# 16  K00972.02            15.77          7.8226        101.60  1.091341e+04  FALSE POSITIVE     Detected period >> catalog — likely harmonic alias
# 19  K06753.01             7.42         72.2820         89.73  1.723694e+05            WEAK            Period mismatch 89.7% — partial signal only
# 22  K03161.01             1.56          6.0941         74.40  1.217742e+07            WEAK            Period mismatch 74.4% — partial signal only
# 24  K00974.01            11.72         53.5058         78.10  2.503082e+03            WEAK            Period mismatch 78.1% — partial signal only
# 31  K01807.01             4.53        132.1342         96.57  7.514218e+03            WEAK            Period mismatch 96.6% — partial signal only
# 33  K00976.01             0.51         52.5690         99.03  3.473036e+04            WEAK            Period mismatch 99.0% — partial signal only
# 37  K07572.01             4.02         91.0699         95.59  2.069510e+01            WEAK            Period mismatch 95.6% — partial signal only
# 40  K03886.01             7.22          5.5665         29.70  2.570366e+04        MODERATE             Period mismatch 29.7% — possible detection
# 42  K00258.01             2.87          4.1574         30.97  1.120412e+05        MODERATE             Period mismatch 31.0% — possible detection
# 43  K07305.01            11.22          3.7292        200.87  2.896659e+03  FALSE POSITIVE  Period mismatch >150% — BLS detected unrelated signal
# 46  K07791.01             2.82        106.1873         97.34  4.285790e+01            WEAK            Period mismatch 97.3% — partial signal only
# 49  K05016.01             0.80          0.5236         52.79  1.757909e+02            WEAK            Period mismatch 52.8% — partial signal only
#
# CLASSIFICATION SUMMARY
# ============================================================
#   WEAK                  10 candidates (50.0%)
#   FALSE POSITIVE         4 candidates (20.0%)
#   STRONG                 4 candidates (20.0%)
#   MODERATE               2 candidates (10.0%)
#
#   TOTAL                 20 unique stars
#
# False positive rate:  20.0%
# Detection rate:       80.0%
# Saved classified results to outputs/v2_candidates_classified.csv
