# %%
import lightkurve as lk
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from astroquery.ipac.nexsci.nasa_exoplanet_archive import NasaExoplanetArchive
import warnings
warnings.filterwarnings('ignore')

# Physical constants
G = 6.674e-11       # Gravitational constant
M_sun = 1.989e30    # Solar mass in kg
R_sun = 6.957e8     # Solar radius in meters
AU = 1.496e11       # 1 AU in meters
# Out:
# C:\Users\giahy\Downloads\anaconda\Lib\site-packages\lightkurve\prf\__init__.py:7: UserWarning: Warning: the tpfmodel submodule is not available without oktopus installed, which requires a current version of autograd. See #1452 for details.
#   warnings.warn(

# %%
koi_table = NasaExoplanetArchive.query_criteria(
    table="koi",
    select="kepid, kepoi_name, koi_period, koi_disposition, koi_kepmag, \
            koi_prad, koi_srad, koi_smass, koi_steff",
    where="koi_disposition like 'CANDIDATE' and koi_kepmag < 14"
)

df = koi_table.to_pandas()

# Filter out missing or invalid stellar data
df_clean = df.dropna(subset=['koi_smass', 'koi_srad', 'koi_period', 'koi_steff'])
df_clean = df_clean[
    (df_clean['koi_smass'] > 0.1) &
    (df_clean['koi_srad'] > 0.1) &
    (df_clean['koi_period'] > 0) &
    (df_clean['koi_steff'] > 0)
].copy()

# Deduplicate — one row per star (brightest signal per star)
df_unique = df_clean.sort_values('koi_kepmag').drop_duplicates(
    subset='kepid', keep='first'
).reset_index(drop=True)

print(f"Total candidates:         {len(df)}")
print(f"With complete data:       {len(df_clean)}")
print(f"Unique stars:             {len(df_unique)}")

# Take 500 brightest unique stars
df_sample = df_unique.head(500).reset_index(drop=True)
print(f"Working sample:           {len(df_sample)} stars")
# Out:
# Total candidates:         3255
# With complete data:       2301
# Unique stars:             914
# Working sample:           500 stars

# %%
def calculate_orbital_distance(period_days, stellar_mass_solar):
    T = period_days * 86400
    M = stellar_mass_solar * M_sun
    a_cubed = (G * M * T**2) / (4 * np.pi**2)
    return (a_cubed ** (1/3)) / AU

def estimate_luminosity(stellar_temp, stellar_radius_solar):
    T_sun = 5778
    return (stellar_radius_solar**2) * ((stellar_temp / T_sun)**4)

def habitable_zone(luminosity_solar):
    inner = 0.95 * np.sqrt(luminosity_solar)
    outer = 1.37 * np.sqrt(luminosity_solar)
    return inner, outer

def classify_planet(radius_earth):
    if radius_earth is None:
        return "Unknown"
    if radius_earth < 1.25:
        return "Rocky"
    elif radius_earth < 2.0:
        return "Super-Earth"
    elif radius_earth < 4.0:
        return "Mini-Neptune"
    elif radius_earth < 11.0:
        return "Gas Giant"
    else:
        return "Super-Jupiter"

# %%
from concurrent.futures import ThreadPoolExecutor
def check_period_match(detected, catalog, threshold=20):
    """
    Check if detected period matches catalog period
    including common harmonics (0.5x, 2x, 3x)
    Returns (verified, match_pct, harmonic_note)
    """
    harmonics = [0.5, 1.0, 1.5, 2.0, 3.0]
    best_match = 999
    best_note = "fundamental"
    
    for h in harmonics:
        match = abs(detected - catalog * h) / (catalog * h) * 100
        if match < best_match:
            best_match = match
            if h == 1.0:
                best_note = "fundamental"
            else:
                best_note = f"{h}x harmonic"
    
    verified = best_match <= threshold
    return verified, round(best_match, 2), best_note

results = []
failed = []
unverified = []

total = len(df_sample)

for idx, row in df_sample.iterrows():
    kepid = str(int(row['kepid']))
    catalog_period = row['koi_period']
    
    print(f"[{idx+1}/{total}] KIC {kepid} "
          f"(catalog period: {catalog_period:.3f}d)...", end=" ")
    
    try:
        # ── STEP 1: Download light curve ──────────────────────
        search = lk.search_lightcurve(
            f"KIC {kepid}",
            mission="Kepler",
            cadence="long"
        )
        
        if len(search) == 0:
            print("No data")
            failed.append({'kepid': kepid, 'reason': 'No light curve found'})
            continue
        
        # Download up to 3 quarters for better period detection
        n_quarters = 1
        lc_list = [search[i].download() for i in range(n_quarters)]
        lc = lk.LightCurveCollection(lc_list).stitch()
        
        # ── STEP 2: Clean ─────────────────────────────────────
        lc = lc.remove_nans().remove_outliers(sigma=3).normalize()
        
        # ── STEP 3: BLS period detection ──────────────────────
        # Cap search at 50 days — beyond this BLS needs much more data
        # Long period planets need many quarters to confirm anyway
        search_max = min(catalog_period * 2, 50)
        search_max = max(search_max, 5)          # minimum search of 5 days
        step = max(0.05, search_max / 500)        # max 500 points in range

        # Scale frequency_factor higher for long period stars
        # to prevent internal grid from becoming too large
        if catalog_period > 50:
            freq_factor = 150
        elif catalog_period > 20:
            freq_factor = 50
        else:
            freq_factor = 25
        
        pg = lc.to_periodogram(
            method="bls",
            period=np.arange(0.5, search_max, step),
            frequency_factor=freq_factor  
        )
        
        detected_period = pg.period_at_max_power.value
        bls_power = pg.max_power.value
        
        # ── STEP 4: Cross-match with NASA catalog ─────────────
        verified, period_match_pct, harmonic_note = check_period_match(
            detected_period, catalog_period
        )

        if not verified:
            print(f"Not verified (best match: {period_match_pct:.1f}%)")
            unverified.append({
                'kepid': kepid,
                'kepoi_name': row['kepoi_name'],
                'catalog_period': round(catalog_period, 4),
                'detected_period': round(detected_period, 4),
                'period_match_pct': round(period_match_pct, 2),
                'bls_power': round(bls_power, 5)
            })
            continue
        
        # ── STEP 5: Calculate physical properties ─────────────
        # Only runs if independently verified
        orbital_dist = calculate_orbital_distance(
            catalog_period,           # Use catalog period for accuracy
            row['koi_smass']
        )
        
        luminosity = estimate_luminosity(row['koi_steff'], row['koi_srad'])
        hz_inner, hz_outer = habitable_zone(luminosity)
        in_hz = hz_inner <= orbital_dist <= hz_outer
        
        planet_radius = row['koi_prad'] if pd.notna(row['koi_prad']) else None
        planet_type = classify_planet(planet_radius)

        print(f"VERIFIED ✓ "
              f"(match: {period_match_pct:.1f}% via {harmonic_note}, "
              f"dist: {orbital_dist:.3f} AU, "
              f"HZ: {in_hz})")
        
        results.append({
            'kepid': kepid,
            'kepoi_name': row['kepoi_name'],
            'catalog_period (days)': round(catalog_period, 4),
            'detected_period (days)': round(detected_period, 4),
            'period_match (%)': round(period_match_pct, 2),
            'period_match_note': harmonic_note,
            'bls_power': round(bls_power, 5),
            'orbital_dist (AU)': round(orbital_dist, 4),
            'planet_radius (R_earth)': planet_radius,
            'planet_type': planet_type,
            'stellar_mass (solar)': round(row['koi_smass'], 3),
            'stellar_temp (K)': round(row['koi_steff'], 0),
            'luminosity (solar)': round(luminosity, 4),
            'hz_inner (AU)': round(hz_inner, 4),
            'hz_outer (AU)': round(hz_outer, 4),
            'in_habitable_zone': in_hz,
            'quarters_used': n_quarters,
            'kepmag': row['koi_kepmag']
        })
        
    except Exception as e:
        print(f"Error: {str(e)[:50]}")
        failed.append({'kepid': kepid, 'reason': str(e)[:100]})
        continue

# Convert to DataFrames
results_df = pd.DataFrame(results)
unverified_df = pd.DataFrame(unverified)
failed_df = pd.DataFrame(failed)

print(f"\n{'='*60}")
print(f"PIPELINE COMPLETE")
print(f"{'='*60}")
print(f"Verified candidates:    {len(results_df)}")
print(f"Not verified:           {len(unverified_df)}")
print(f"Failed (no data):       {len(failed_df)}")
print(f"Verification rate:      {len(results_df)/total*100:.1f}%")
# Out:
# [1/500] KIC 11502218 (catalog period: 3.989d)... VERIFIED ✓ (match: 12.2% via 2.0x harmonic, dist: 0.062 AU, HZ: False)
# [2/500] KIC 11180361 (catalog period: 0.533d)... VERIFIED ✓ (match: 0.1% via 3.0x harmonic, dist: 0.017 AU, HZ: False)
# [3/500] KIC 5108214 (catalog period: 2.119d)... VERIFIED ✓ (match: 0.9% via fundamental, dist: 0.036 AU, HZ: False)
# [4/500] KIC 4150611 (catalog period: 0.761d)... Not verified (best match: 31.4%)
# [5/500] KIC 6032730 (catalog period: 96.509d)... Not verified (best match: 91.7%)
# [6/500] KIC 11709006 (catalog period: 0.720d)... VERIFIED ✓ (match: 1.9% via 3.0x harmonic, dist: 0.016 AU, HZ: False)
# [7/500] KIC 7022603 (catalog period: 21.127d)... VERIFIED ✓ (match: 12.1% via 0.5x harmonic, dist: 0.176 AU, HZ: False)
# [8/500] KIC 3230227 (catalog period: 7.047d)... Not verified (best match: 84.4%)
# [9/500] KIC 11013201 (catalog period: 7.823d)... VERIFIED ✓ (match: 10.5% via fundamental, dist: 0.098 AU, HZ: False)
# [10/500] KIC 6670742 (catalog period: 72.282d)... Not verified (best match: 85.3%)
# [11/500] KIC 2696703 (catalog period: 6.094d)... Not verified (best match: 49.1%)
# [12/500] KIC 9414417 (catalog period: 53.506d)... Not verified (best match: 89.5%)
# [13/500] KIC 10614012 (catalog period: 132.134d)... Not verified (best match: 93.0%)
# [14/500] KIC 3441784 (catalog period: 52.569d)... Not verified (best match: 79.1%)
# [15/500] KIC 6876575 (catalog period: 91.070d)... Not verified (best match: 91.2%)
# [16/500] KIC 8848288 (catalog period: 5.567d)... VERIFIED ✓ (match: 13.8% via 1.5x harmonic, dist: 0.079 AU, HZ: False)
# [17/500] KIC 10290021 (catalog period: 3.729d)... VERIFIED ✓ (match: 6.4% via 1.5x harmonic, dist: 0.052 AU, HZ: False)
# [18/500] KIC 6790592 (catalog period: 106.187d)... Not verified (best match: 94.7%)
# [19/500] KIC 3848948 (catalog period: 0.524d)... VERIFIED ✓ (match: 1.9% via 1.5x harmonic, dist: 0.017 AU, HZ: False)
# [20/500] KIC 7296438 (catalog period: 173.929d)... Not verified (best match: 99.2%)
# [21/500] KIC 9955262 (catalog period: 77.480d)... Not verified (best match: 88.1%)
# [22/500] KIC 1025986 (catalog period: 275.074d)... Not verified (best match: 97.5%)
# [23/500] KIC 5598639 (catalog period: 0.649d)... VERIFIED ✓ (match: 0.2% via fundamental, dist: 0.014 AU, HZ: False)
# [24/500] KIC 9697131 (catalog period: 3.098d)... VERIFIED ✓ (match: 5.6% via 2.0x harmonic, dist: 0.046 AU, HZ: False)
# [25/500] KIC 8552540 (catalog period: 0.531d)... VERIFIED ✓ (match: 3.6% via 2.0x harmonic, dist: 0.013 AU, HZ: False)
# [26/500] KIC 9579208 (catalog period: 4.118d)... VERIFIED ✓ (match: 2.0% via 0.5x harmonic, dist: 0.055 AU, HZ: False)
# [27/500] KIC 8176564 (catalog period: 6.572d)... Not verified (best match: 39.1%)
# [28/500] KIC 12167361 (catalog period: 47.931d)... Not verified (best match: 96.2%)
# [29/500] KIC 9457728 (catalog period: 4.380d)... VERIFIED ✓ (match: 1.2% via 2.0x harmonic, dist: 0.056 AU, HZ: False)
# [30/500] KIC 7352727 (catalog period: 2.456d)... VERIFIED ✓ (match: 13.5% via 2.0x harmonic, dist: 0.045 AU, HZ: False)
# [31/500] KIC 4450844 (catalog period: 56.348d)... Not verified (best match: 80.8%)
# [32/500] KIC 4945877 (catalog period: 1.340d)... VERIFIED ✓ (match: 19.1% via 3.0x harmonic, dist: 0.031 AU, HZ: False)
# [33/500] KIC 12168280 (catalog period: 229.958d)... Not verified (best match: 97.0%)
# [34/500] KIC 11192141 (catalog period: 1.354d)... VERIFIED ✓ (match: 11.4% via 1.5x harmonic, dist: 0.023 AU, HZ: False)
# [35/500] KIC 6117415 (catalog period: 19.742d)... Not verified (best match: 32.5%)
# [36/500] KIC 9268159 (catalog period: 185.975d)... Not verified (best match: 94.3%)
# [37/500] KIC 3425851 (catalog period: 110.378d)... Not verified (best match: 85.5%)
# [38/500] KIC 8718273 (catalog period: 3.480d)... Not verified (best match: 26.7%)
# [39/500] KIC 4269252 (catalog period: 9.402d)... VERIFIED ✓ (match: 12.8% via fundamental, dist: 0.107 AU, HZ: False)
# [40/500] KIC 9418619 (catalog period: 6.150d)... VERIFIED ✓ (match: 7.3% via 0.5x harmonic, dist: 0.087 AU, HZ: False)
# [41/500] KIC 10214328 (catalog period: 659.346d)... Not verified (best match: 99.5%)
# [42/500] KIC 2697935 (catalog period: 21.513d)... VERIFIED ✓ (match: 0.1% via fundamental, dist: 0.175 AU, HZ: False)
# [43/500] KIC 12021387 (catalog period: 241.072d)... Not verified (best match: 95.0%)
# [44/500] KIC 8197761 (catalog period: 9.869d)... Not verified (best match: 80.8%)
# [45/500] KIC 7887791 (catalog period: 2.229d)... VERIFIED ✓ (match: 1.7% via 1.5x harmonic, dist: 0.032 AU, HZ: False)
# [46/500] KIC 5564082 (catalog period: 2.706d)... VERIFIED ✓ (match: 3.0% via 2.0x harmonic, dist: 0.036 AU, HZ: False)
# [47/500] KIC 4147444 (catalog period: 1.804d)... VERIFIED ✓ (match: 17.8% via 2.0x harmonic, dist: 0.030 AU, HZ: False)
# [48/500] KIC 5513648 (catalog period: 32.859d)... Not verified (best match: 64.1%)
# [49/500] KIC 7199397 (catalog period: 105.885d)... Not verified (best match: 96.4%)
# [50/500] KIC 10191056 (catalog period: 1.214d)... VERIFIED ✓ (match: 3.0% via fundamental, dist: 0.025 AU, HZ: False)
# [51/500] KIC 10514430 (catalog period: 20.719d)... VERIFIED ✓ (match: 9.6% via 1.5x harmonic, dist: 0.148 AU, HZ: False)
# [52/500] KIC 5380812 (catalog period: 16.214d)... Not verified (best match: 90.6%)
# [53/500] KIC 3545840 (catalog period: 54.292d)... Not verified (best match: 89.7%)
# [54/500] KIC 6266866 (catalog period: 232.916d)... Not verified (best match: 94.7%)
# [55/500] KIC 8279146 (catalog period: 93.360d)... Not verified (best match: 88.9%)
# [56/500] KIC 4769799 (catalog period: 21.929d)... VERIFIED ✓ (match: 11.4% via 0.5x harmonic, dist: 0.147 AU, HZ: False)
# [57/500] KIC 5460434 (catalog period: 50.564d)... Not verified (best match: 86.5%)
# [58/500] KIC 7431665 (catalog period: 281.503d)... Not verified (best match: 98.4%)
# [59/500] KIC 10155286 (catalog period: 333.486d)... Not verified (best match: 97.4%)
# [60/500] KIC 8297017 (catalog period: 128.209d)... Not verified (best match: 84.7%)
# [61/500] KIC 7222086 (catalog period: 2.439d)... Not verified (best match: 30.3%)
# [62/500] KIC 6268648 (catalog period: 94.094d)... Not verified (best match: 96.8%)
# [63/500] KIC 3119256 (catalog period: 4.142d)... VERIFIED ✓ (match: 13.1% via 0.5x harmonic, dist: 0.051 AU, HZ: False)
# [64/500] KIC 9775385 (catalog period: 45.163d)... Not verified (best match: 96.9%)
# [65/500] KIC 11251991 (catalog period: 134.359d)... Not verified (best match: 95.5%)
# [66/500] KIC 8868481 (catalog period: 388.048d)... Not verified (best match: 99.1%)
# [67/500] KIC 11338091 (catalog period: 293.386d)... Not verified (best match: 94.9%)
# [68/500] KIC 4851217 (catalog period: 2.470d)... VERIFIED ✓ (match: 1.2% via 0.5x harmonic, dist: 0.041 AU, HZ: False)
# [69/500] KIC 11098013 (catalog period: 7.508d)... VERIFIED ✓ (match: 6.5% via 1.5x harmonic, dist: 0.083 AU, HZ: False)
# [70/500] KIC 9475697 (catalog period: 206.801d)... Not verified (best match: 94.5%)
# [71/500] KIC 9173014 (catalog period: 151.779d)... Not verified (best match: 99.0%)
# [72/500] KIC 9166700 (catalog period: 264.467d)... Not verified (best match: 97.4%)
# [73/500] KIC 3003992 (catalog period: 13.555d)... Not verified (best match: 88.6%)
# [74/500] KIC 4735826 (catalog period: 4.020d)... Not verified (best match: 30.4%)
# [75/500] KIC 9178894 (catalog period: 113.993d)... Not verified (best match: 90.2%)
# [76/500] KIC 8396660 (catalog period: 1.338d)... VERIFIED ✓ (match: 5.3% via 3.0x harmonic, dist: 0.026 AU, HZ: False)
# [77/500] KIC 8652997 (catalog period: 362.222d)... Not verified (best match: 99.1%)
# [78/500] KIC 11623629 (catalog period: 117.761d)... Not verified (best match: 93.2%)
# [79/500] KIC 2013883 (catalog period: 0.765d)... Not verified (best match: 100.5%)
# [80/500] KIC 11081504 (catalog period: 13.123d)... Not verified (best match: 80.4%)
# [81/500] KIC 3831523 (catalog period: 1.529d)... VERIFIED ✓ (match: 1.4% via fundamental, dist: 0.028 AU, HZ: False)
# [82/500] KIC 1575873 (catalog period: 0.629d)... Not verified (best match: 77.5%)
# [83/500] KIC 3439031 (catalog period: 2.976d)... VERIFIED ✓ (match: 0.9% via fundamental, dist: 0.042 AU, HZ: False)
# [84/500] KIC 4160669 (catalog period: 2.184d)... VERIFIED ✓ (match: 0.8% via 1.5x harmonic, dist: 0.018 AU, HZ: False)
# [85/500] KIC 10967168 (catalog period: 22.266d)... VERIFIED ✓ (match: 16.3% via 0.5x harmonic, dist: 0.172 AU, HZ: False)
# [86/500] KIC 11970288 (catalog period: 20.711d)... Not verified (best match: 32.8%)
# [87/500] KIC 9552608 (catalog period: 9.251d)... Not verified (best match: 83.8%)
# [88/500] KIC 3532985 (catalog period: 5.289d)... VERIFIED ✓ (match: 6.4% via fundamental, dist: 0.079 AU, HZ: False)
# [89/500] KIC 5617510 (catalog period: 74.372d)... Not verified (best match: 87.4%)
# [90/500] KIC 7625138 (catalog period: 5.720d)... VERIFIED ✓ (match: 2.1% via 0.5x harmonic, dist: 0.067 AU, HZ: False)
# [91/500] KIC 4663185 (catalog period: 56.699d)... Not verified (best match: 88.7%)
# [92/500] KIC 12402588 (catalog period: 97.942d)... Not verified (best match: 82.4%)
# [93/500] KIC 10272858 (catalog period: 584.556d)... Not verified (best match: 99.7%)
# [94/500] KIC 7255336 (catalog period: 1.203d)... VERIFIED ✓ (match: 0.3% via 2.0x harmonic, dist: 0.022 AU, HZ: False)
# [95/500] KIC 6603043 (catalog period: 110.322d)... Not verified (best match: 95.5%)
# [96/500] KIC 5444392 (catalog period: 0.760d)... VERIFIED ✓ (match: 1.3% via fundamental, dist: 0.016 AU, HZ: False)
# [97/500] KIC 5391911 (catalog period: 0.782d)... VERIFIED ✓ (match: 4.1% via fundamental, dist: 0.021 AU, HZ: False)
# [98/500] KIC 6891512 (catalog period: 1.753d)... VERIFIED ✓ (match: 1.3% via 2.0x harmonic, dist: 0.029 AU, HZ: False)
# [99/500] KIC 5524229 (catalog period: 22.493d)... VERIFIED ✓ (match: 14.8% via 0.5x harmonic, dist: 0.186 AU, HZ: False)
# [100/500] KIC 5802205 (catalog period: 578.888d)... Not verified (best match: 99.8%)
# [101/500] KIC 10514429 (catalog period: 20.719d)... VERIFIED ✓ (match: 8.8% via fundamental, dist: 0.145 AU, HZ: False)
# [102/500] KIC 11551652 (catalog period: 3.774d)... VERIFIED ✓ (match: 0.6% via 2.0x harmonic, dist: 0.054 AU, HZ: False)
# [103/500] KIC 7103300 (catalog period: 3.226d)... Not verified (best match: 56.6%)
# [104/500] KIC 8517303 (catalog period: 24.076d)... Not verified (best match: 65.5%)
# [105/500] KIC 7429287 (catalog period: 84.800d)... Not verified (best match: 96.0%)
# [106/500] KIC 5985713 (catalog period: 8.953d)... Not verified (best match: 56.4%)
# [107/500] KIC 11282568 (catalog period: 1.320d)... Not verified (best match: 28.7%)
# [108/500] KIC 8009811 (catalog period: 53.554d)... Not verified (best match: 74.2%)
# [109/500] KIC 10467815 (catalog period: 371.176d)... Not verified (best match: 96.1%)
# [110/500] KIC 5795648 (catalog period: 4.553d)... VERIFIED ✓ (match: 5.6% via fundamental, dist: 0.054 AU, HZ: False)
# [111/500] KIC 7375348 (catalog period: 47.744d)... Not verified (best match: 92.9%)
# [112/500] KIC 9394953 (catalog period: 100.494d)... Not verified (best match: 89.7%)
# [113/500] KIC 7430876 (catalog period: 32.612d)... VERIFIED ✓ (match: 4.7% via 1.5x harmonic, dist: 0.200 AU, HZ: False)
# [114/500] KIC 12004971 (catalog period: 10.813d)... VERIFIED ✓ (match: 12.6% via fundamental, dist: 0.105 AU, HZ: False)
# [115/500] KIC 10187017 (catalog period: 22.410d)... Not verified (best match: 40.3%)
# [116/500] KIC 5263802 (catalog period: 3.350d)... VERIFIED ✓ (match: 0.0% via fundamental, dist: 0.051 AU, HZ: False)
# [117/500] KIC 4075067 (catalog period: 17.748d)... Not verified (best match: 84.8%)
# [118/500] KIC 7206422 (catalog period: 50.551d)... Not verified (best match: 69.5%)
# [119/500] KIC 4832197 (catalog period: 0.948d)... VERIFIED ✓ (match: 0.2% via fundamental, dist: 0.018 AU, HZ: False)
# [120/500] KIC 8453324 (catalog period: 1.262d)... Not verified (best match: 22.8%)
# [121/500] KIC 9002538 (catalog period: 4.961d)... VERIFIED ✓ (match: 14.0% via 1.5x harmonic, dist: 0.061 AU, HZ: False)
# [122/500] KIC 5695396 (catalog period: 9.488d)... Not verified (best match: 26.2%)
# [123/500] KIC 8443527 (catalog period: 22.600d)... Not verified (best match: 47.6%)
# [124/500] KIC 8302455 (catalog period: 2.442d)... VERIFIED ✓ (match: 3.8% via 2.0x harmonic, dist: 0.037 AU, HZ: False)
# [125/500] KIC 9015738 (catalog period: 34.775d)... VERIFIED ✓ (match: 16.3% via fundamental, dist: 0.218 AU, HZ: False)
# [126/500] KIC 8223568 (catalog period: 143.097d)... Not verified (best match: 97.2%)
# [127/500] KIC 3240049 (catalog period: 2.945d)... VERIFIED ✓ (match: 9.5% via 1.5x harmonic, dist: 0.051 AU, HZ: False)
# [128/500] KIC 9822284 (catalog period: 0.970d)... Not verified (best match: 49.5%)
# [129/500] KIC 5131276 (catalog period: 0.669d)... Not verified (best match: 131.8%)
# [130/500] KIC 11506938 (catalog period: 22.576d)... Not verified (best match: 39.6%)
# [131/500] KIC 8096395 (catalog period: 366.084d)... Not verified (best match: 95.6%)
# [132/500] KIC 8005002 (catalog period: 578.216d)... Not verified (best match: 97.8%)
# [133/500] KIC 8590527 (catalog period: 0.740d)... VERIFIED ✓ (match: 1.4% via fundamental, dist: 0.017 AU, HZ: False)
# [134/500] KIC 12016267 (catalog period: 22.791d)... Not verified (best match: 70.8%)
# [135/500] KIC 7592529 (catalog period: 75.907d)... Not verified (best match: 95.5%)
# [136/500] KIC 4953262 (catalog period: 105.590d)... Not verified (best match: 82.8%)
# [137/500] KIC 4680772 (catalog period: 26.190d)... Not verified (best match: 93.1%)
# [138/500] KIC 9469494 (catalog period: 275.560d)... Not verified (best match: 97.8%)
# [139/500] KIC 8554498 (catalog period: 4.780d)... Not verified (best match: 79.1%)
# [140/500] KIC 4049901 (catalog period: 16.291d)... Not verified (best match: 71.5%)
# [141/500] KIC 7746958 (catalog period: 1.205d)... VERIFIED ✓ (match: 5.1% via 3.0x harmonic, dist: 0.022 AU, HZ: False)
# [142/500] KIC 3101178 (catalog period: 59.404d)... Not verified (best match: 89.6%)
# [143/500] KIC 10982373 (catalog period: 2.003d)... VERIFIED ✓ (match: 2.4% via fundamental, dist: 0.040 AU, HZ: False)
# [144/500] KIC 8509781 (catalog period: 70.336d)... Not verified (best match: 94.6%)
# [145/500] KIC 8212002 (catalog period: 9.554d)... VERIFIED ✓ (match: 13.1% via fundamental, dist: 0.095 AU, HZ: False)
# [146/500] KIC 3545478 (catalog period: 75.112d)... Not verified (best match: 89.1%)
# [147/500] KIC 6515722 (catalog period: 1.909d)... VERIFIED ✓ (match: 2.2% via fundamental, dist: 0.040 AU, HZ: False)
# [148/500] KIC 9872292 (catalog period: 10.192d)... VERIFIED ✓ (match: 8.3% via fundamental, dist: 0.097 AU, HZ: False)
# [149/500] KIC 8801343 (catalog period: 2.740d)... VERIFIED ✓ (match: 5.8% via fundamental, dist: 0.040 AU, HZ: False)
# [150/500] KIC 7905106 (catalog period: 4.224d)... VERIFIED ✓ (match: 8.9% via fundamental, dist: 0.049 AU, HZ: False)
# [151/500] KIC 4276716 (catalog period: 20.665d)... VERIFIED ✓ (match: 12.8% via 0.5x harmonic, dist: 0.129 AU, HZ: False)
# [152/500] KIC 11856178 (catalog period: 9.133d)... VERIFIED ✓ (match: 16.8% via 0.5x harmonic, dist: 0.087 AU, HZ: False)
# [153/500] KIC 5308778 (catalog period: 20.283d)... Not verified (best match: 42.3%)
# [154/500] KIC 4262040 (catalog period: 92.465d)... Not verified (best match: 87.9%)
# [155/500] KIC 6779260 (catalog period: 2.217d)... VERIFIED ✓ (match: 11.7% via 2.0x harmonic, dist: 0.032 AU, HZ: False)
# [156/500] KIC 3122872 (catalog period: 96.817d)... Not verified (best match: 93.8%)
# [157/500] KIC 4848423 (catalog period: 1.502d)... VERIFIED ✓ (match: 0.1% via fundamental, dist: 0.024 AU, HZ: False)
# [158/500] KIC 11456279 (catalog period: 0.573d)... VERIFIED ✓ (match: 10.5% via 1.5x harmonic, dist: 0.016 AU, HZ: False)
# [159/500] KIC 9602613 (catalog period: 7.573d)... Not verified (best match: 86.8%)
# [160/500] KIC 5612697 (catalog period: 15.152d)... Not verified (best match: 93.4%)
# [161/500] KIC 4144236 (catalog period: 10.005d)... Not verified (best match: 20.9%)
# [162/500] KIC 5617259 (catalog period: 1.048d)... VERIFIED ✓ (match: 3.4% via 3.0x harmonic, dist: 0.025 AU, HZ: False)
# [163/500] KIC 6035335 (catalog period: 1.044d)... VERIFIED ✓ (match: 9.0% via fundamental, dist: 0.023 AU, HZ: False)
# [164/500] KIC 5394585 (catalog period: 151.130d)... Not verified (best match: 98.2%)
# [165/500] KIC 9518710 (catalog period: 0.954d)... VERIFIED ✓ (match: 0.5% via fundamental, dist: 0.023 AU, HZ: False)
# [166/500] KIC 8703129 (catalog period: 253.375d)... Not verified (best match: 99.0%)
# [167/500] KIC 10155029 (catalog period: 2.132d)... Not verified (best match: 29.6%)
# [168/500] KIC 10464199 (catalog period: 198.113d)... Not verified (best match: 97.5%)
# [169/500] KIC 8873090 (catalog period: 10.164d)... Not verified (best match: 20.3%)
# [170/500] KIC 7017274 (catalog period: 11.913d)... Not verified (best match: 31.6%)
# [171/500] KIC 9655005 (catalog period: 1.399d)... VERIFIED ✓ (match: 10.8% via fundamental, dist: 0.032 AU, HZ: False)
# [172/500] KIC 8873873 (catalog period: 295.061d)... Not verified (best match: 99.5%)
# [173/500] KIC 7838906 (catalog period: 35.426d)... Not verified (best match: 89.3%)
# [174/500] KIC 2850321 (catalog period: 25.222d)... Not verified (best match: 31.0%)
# [175/500] KIC 5738698 (catalog period: 2.404d)... VERIFIED ✓ (match: 0.2% via fundamental, dist: 0.035 AU, HZ: False)
# [176/500] KIC 7914906 (catalog period: 8.753d)... Not verified (best match: 63.4%)
# [177/500] KIC 8345384 (catalog period: 42.101d)... Not verified (best match: 53.4%)
# [178/500] KIC 5398002 (catalog period: 14.161d)... Not verified (best match: 80.9%)
# [179/500] KIC 10399321 (catalog period: 21.581d)... VERIFIED ✓ (match: 4.3% via 1.5x harmonic, dist: 0.155 AU, HZ: False)
# [180/500] KIC 12735793 (catalog period: 37.794d)... Not verified (best match: 48.7%)
# [181/500] KIC 4048898 (catalog period: 13.091d)... Not verified (best match: 50.8%)
# [182/500] KIC 4996057 (catalog period: 4.830d)... VERIFIED ✓ (match: 8.9% via fundamental, dist: 0.054 AU, HZ: False)
# [183/500] KIC 11869052 (catalog period: 20.546d)... Not verified (best match: 44.7%)
# [184/500] KIC 7983117 (catalog period: 25.090d)... Not verified (best match: 77.7%)
# [185/500] KIC 12456063 (catalog period: 17.801d)... VERIFIED ✓ (match: 18.4% via 0.5x harmonic, dist: 0.135 AU, HZ: False)
# [186/500] KIC 7287683 (catalog period: 69.835d)... Not verified (best match: 96.8%)
# [187/500] KIC 9214176 (catalog period: 348.666d)... Not verified (best match: 94.6%)
# [188/500] KIC 9906489 (catalog period: 8.965d)... Not verified (best match: 36.4%)
# [189/500] KIC 8494783 (catalog period: 58.926d)... Not verified (best match: 81.0%)
# [190/500] KIC 9588822 (catalog period: 61.859d)... Not verified (best match: 90.0%)
# [191/500] KIC 8007675 (catalog period: 2.352d)... VERIFIED ✓ (match: 8.6% via fundamental, dist: 0.037 AU, HZ: False)
# [192/500] KIC 5174492 (catalog period: 0.721d)... Not verified (best match: 80.4%)
# [193/500] KIC 11187972 (catalog period: 37.465d)... Not verified (best match: 92.5%)
# [194/500] KIC 9145861 (catalog period: 42.297d)... Not verified (best match: 97.6%)
# [195/500] KIC 5390913 (catalog period: 1.680d)... VERIFIED ✓ (match: 1.2% via 0.5x harmonic, dist: 0.025 AU, HZ: False)
# [196/500] KIC 11820830 (catalog period: 12.732d)... Not verified (best match: 83.3%)
# [197/500] KIC 5894182 (catalog period: 494.485d)... Not verified (best match: 97.9%)
# [198/500] KIC 5716763 (catalog period: 1.281d)... VERIFIED ✓ (match: 1.5% via fundamental, dist: 0.022 AU, HZ: False)
# [199/500] KIC 11097752 (catalog period: 359.846d)... Not verified (best match: 85.9%)
# [200/500] KIC 4139254 (catalog period: 485.923d)... Not verified (best match: 96.0%)
# [201/500] KIC 10616656 (catalog period: 25.285d)... Not verified (best match: 82.6%)
# [202/500] KIC 9221398 (catalog period: 13.788d)... Not verified (best match: 30.4%)
# [203/500] KIC 10932270 (catalog period: 27.584d)... Not verified (best match: 54.3%)
# [204/500] KIC 6763884 (catalog period: 2.447d)... VERIFIED ✓ (match: 9.0% via 1.5x harmonic, dist: 0.036 AU, HZ: False)
# [205/500] KIC 3542573 (catalog period: 3.471d)... VERIFIED ✓ (match: 1.3% via 2.0x harmonic, dist: 0.049 AU, HZ: False)
# [206/500] KIC 10384298 (catalog period: 3.439d)... VERIFIED ✓ (match: 7.6% via fundamental, dist: 0.042 AU, HZ: False)
# [207/500] KIC 5652983 (catalog period: 498.393d)... Not verified (best match: 99.4%)
# [208/500] KIC 6837283 (catalog period: 21.118d)... Not verified (best match: 44.9%)
# [209/500] KIC 3109550 (catalog period: 4.875d)... VERIFIED ✓ (match: 0.5% via 0.5x harmonic, dist: 0.055 AU, HZ: False)
# [210/500] KIC 5544450 (catalog period: 6.937d)... Not verified (best match: 59.6%)
# [211/500] KIC 6307083 (catalog period: 3.178d)... VERIFIED ✓ (match: 7.2% via 2.0x harmonic, dist: 0.039 AU, HZ: False)
# [212/500] KIC 10480952 (catalog period: 2.037d)... VERIFIED ✓ (match: 3.1% via fundamental, dist: 0.034 AU, HZ: False)
# [213/500] KIC 5986270 (catalog period: 1.535d)... VERIFIED ✓ (match: 10.8% via 2.0x harmonic, dist: 0.034 AU, HZ: False)
# [214/500] KIC 7974634 (catalog period: 75.073d)... Not verified (best match: 92.8%)
# [215/500] KIC 11817750 (catalog period: 9.763d)... VERIFIED ✓ (match: 16.8% via 0.5x harmonic, dist: 0.104 AU, HZ: False)
# [216/500] KIC 12401859 (catalog period: 22.863d)... Not verified (best match: 55.6%)
# [217/500] KIC 3240159 (catalog period: 82.138d)... Not verified (best match: 93.2%)
# [218/500] KIC 6470149 (catalog period: 165.742d)... Not verified (best match: 62.8%)
# [219/500] KIC 9288237 (catalog period: 7.491d)... Not verified (best match: 65.3%)
# [220/500] KIC 11804437 (catalog period: 449.015d)... Not verified (best match: 96.3%)
# [221/500] KIC 9780149 (catalog period: 2.506d)... VERIFIED ✓ (match: 0.2% via fundamental, dist: 0.036 AU, HZ: False)
# [222/500] KIC 10685764 (catalog period: 17.634d)... Not verified (best match: 35.9%)
# [223/500] KIC 7902003 (catalog period: 7.130d)... Not verified (best match: 50.9%)
# [224/500] KIC 6198182 (catalog period: 5.178d)... VERIFIED ✓ (match: 13.1% via 1.5x harmonic, dist: 0.059 AU, HZ: False)
# [225/500] KIC 11336883 (catalog period: 54.326d)... Not verified (best match: 85.6%)
# [226/500] KIC 11290515 (catalog period: 5.894d)... VERIFIED ✓ (match: 3.5% via 0.5x harmonic, dist: 0.066 AU, HZ: False)
# [227/500] KIC 5819801 (catalog period: 11.831d)... Not verified (best match: 25.9%)
# [228/500] KIC 7672940 (catalog period: 580.000d)... Not verified (best match: 98.5%)
# [229/500] KIC 11456256 (catalog period: 61.610d)... Not verified (best match: 92.9%)
# [230/500] KIC 3129238 (catalog period: 2.009d)... VERIFIED ✓ (match: 2.9% via 1.5x harmonic, dist: 0.028 AU, HZ: False)
# [231/500] KIC 12253474 (catalog period: 6.423d)... VERIFIED ✓ (match: 13.7% via fundamental, dist: 0.069 AU, HZ: False)
# [232/500] KIC 4044005 (catalog period: 17.512d)... VERIFIED ✓ (match: 5.5% via 0.5x harmonic, dist: 0.133 AU, HZ: False)
# [233/500] KIC 8307489 (catalog period: 421.982d)... Not verified (best match: 99.5%)
# [234/500] KIC 10978581 (catalog period: 277.114d)... Not verified (best match: 93.9%)
# [235/500] KIC 10907307 (catalog period: 277.251d)... Not verified (best match: 86.2%)
# [236/500] KIC 10552263 (catalog period: 313.828d)... Not verified (best match: 97.8%)
# [237/500] KIC 6309307 (catalog period: 438.984d)... Not verified (best match: 98.6%)
# [238/500] KIC 3660581 (catalog period: 4.725d)... Not verified (best match: 38.6%)
# [239/500] KIC 5734702 (catalog period: 392.473d)... Not verified (best match: 99.5%)
# [240/500] KIC 4764969 (catalog period: 0.602d)... Not verified (best match: 96.5%)
# [241/500] KIC 2861298 (catalog period: 581.729d)... Not verified (best match: 98.9%)
# [242/500] KIC 6145939 (catalog period: 17.745d)... Not verified (best match: 80.8%)
# [243/500] KIC 8848104 (catalog period: 0.825d)... VERIFIED ✓ (match: 0.0% via 2.0x harmonic, dist: 0.016 AU, HZ: False)
# [244/500] KIC 6928906 (catalog period: 1.549d)... VERIFIED ✓ (match: 10.7% via 3.0x harmonic, dist: 0.033 AU, HZ: False)
# [245/500] KIC 5650930 (catalog period: 455.195d)... Not verified (best match: 98.7%)
# [246/500] KIC 6850665 (catalog period: 214.718d)... Not verified (best match: 92.8%)
# [247/500] KIC 8395870 (catalog period: 74.834d)... Not verified (best match: 98.1%)
# [248/500] KIC 8937555 (catalog period: 113.574d)... Not verified (best match: 81.2%)
# [249/500] KIC 4548011 (catalog period: 9.087d)... Not verified (best match: 38.4%)
# [250/500] KIC 9217583 (catalog period: 222.281d)... Not verified (best match: 98.9%)
# [251/500] KIC 12418816 (catalog period: 0.761d)... VERIFIED ✓ (match: 1.4% via 2.0x harmonic, dist: 0.013 AU, HZ: False)
# [252/500] KIC 9006186 (catalog period: 2.193d)... VERIFIED ✓ (match: 14.0% via 1.5x harmonic, dist: 0.032 AU, HZ: False)
# [253/500] KIC 10917433 (catalog period: 6.913d)... Not verified (best match: 85.5%)
# [254/500] KIC 3547178 (catalog period: 8.177d)... VERIFIED ✓ (match: 8.0% via 2.0x harmonic, dist: 0.080 AU, HZ: False)
# [255/500] KIC 4150972 (catalog period: 161.538d)... Not verified (best match: 87.1%)
# [256/500] KIC 10879899 (catalog period: 169.415d)... Not verified (best match: 93.3%)
# [257/500] KIC 5858919 (catalog period: 218.771d)... Not verified (best match: 95.0%)
# [258/500] KIC 5954894 (catalog period: 48.246d)... Not verified (best match: 88.0%)
# [259/500] KIC 12602999 (catalog period: 8.277d)... VERIFIED ✓ (match: 11.2% via 0.5x harmonic, dist: 0.094 AU, HZ: False)
# [260/500] KIC 11775507 (catalog period: 144.103d)... Not verified (best match: 97.0%)
# [261/500] KIC 8165617 (catalog period: 214.013d)... Not verified (best match: 93.8%)
# [262/500] KIC 10066755 (catalog period: 2.465d)... VERIFIED ✓ (match: 12.8% via fundamental, dist: 0.040 AU, HZ: False)
# [263/500] KIC 11147785 (catalog period: 217.170d)... Not verified (best match: 95.5%)
# [264/500] KIC 4072271 (catalog period: 219.206d)... Not verified (best match: 99.1%)
# [265/500] KIC 8112013 (catalog period: 1.791d)... VERIFIED ✓ (match: 0.5% via 0.5x harmonic, dist: 0.030 AU, HZ: False)
# [266/500] KIC 8758161 (catalog period: 0.998d)... VERIFIED ✓ (match: 0.2% via fundamental, dist: 0.021 AU, HZ: False)
# [267/500] KIC 9026248 (catalog period: 341.558d)... Not verified (best match: 97.5%)
# [268/500] KIC 5436455 (catalog period: 209.968d)... Not verified (best match: 96.8%)
# [269/500] KIC 7009548 (catalog period: 15.186d)... Not verified (best match: 58.2%)
# [270/500] KIC 5130740 (catalog period: 210.306d)... Not verified (best match: 94.7%)
# [271/500] KIC 9957668 (catalog period: 30.695d)... Not verified (best match: 64.8%)
# [272/500] KIC 4346339 (catalog period: 493.742d)... Not verified (best match: 96.2%)
# [273/500] KIC 7282470 (catalog period: 520.655d)... Not verified (best match: 99.3%)
# [274/500] KIC 5563057 (catalog period: 1.049d)... VERIFIED ✓ (match: 0.1% via fundamental, dist: 0.023 AU, HZ: False)
# [275/500] KIC 11969988 (catalog period: 2.191d)... Not verified (best match: 54.4%)
# [276/500] KIC 4770798 (catalog period: 651.074d)... Not verified (best match: 99.2%)
# [277/500] KIC 9724993 (catalog period: 7.863d)... VERIFIED ✓ (match: 3.4% via 1.5x harmonic, dist: 0.081 AU, HZ: False)
# [278/500] KIC 4950557 (catalog period: 24.715d)... Not verified (best match: 59.1%)
# [279/500] KIC 9157523 (catalog period: 192.139d)... Not verified (best match: 90.4%)
# [280/500] KIC 4245897 (catalog period: 11.258d)... VERIFIED ✓ (match: 7.5% via 0.5x harmonic, dist: 0.108 AU, HZ: False)
# [281/500] KIC 2305543 (catalog period: 0.681d)... VERIFIED ✓ (match: 0.9% via 2.0x harmonic, dist: 0.014 AU, HZ: False)
# [282/500] KIC 6029239 (catalog period: 5.518d)... VERIFIED ✓ (match: 18.4% via 1.5x harmonic, dist: 0.061 AU, HZ: False)
# [283/500] KIC 2834805 (catalog period: 25.003d)... Not verified (best match: 35.2%)
# [284/500] KIC 8741367 (catalog period: 0.989d)... Not verified (best match: 58.5%)
# [285/500] KIC 3230787 (catalog period: 17.734d)... Not verified (best match: 44.0%)
# [286/500] KIC 10163067 (catalog period: 25.915d)... Not verified (best match: 77.6%)
# [287/500] KIC 8197406 (catalog period: 4.155d)... Not verified (best match: 61.5%)
# [288/500] KIC 8579684 (catalog period: 2.088d)... VERIFIED ✓ (match: 19.7% via 0.5x harmonic, dist: 0.035 AU, HZ: False)
# [289/500] KIC 9286088 (catalog period: 14.816d)... Not verified (best match: 73.2%)
# [290/500] KIC 10656842 (catalog period: 82.508d)... Not verified (best match: 77.5%)
# [291/500] KIC 8242350 (catalog period: 6.993d)... Not verified (best match: 27.3%)
# [292/500] KIC 4055765 (catalog period: 9.966d)... Not verified (best match: 42.8%)
# [293/500] KIC 9109857 (catalog period: 1.792d)... VERIFIED ✓ (match: 0.5% via fundamental, dist: 0.030 AU, HZ: False)
# [294/500] KIC 8076215 (catalog period: 97.514d)... Not verified (best match: 90.0%)
# [295/500] KIC 2305866 (catalog period: 115.231d)... Not verified (best match: 95.5%)
# [296/500] KIC 10198225 (catalog period: 11.945d)... Not verified (best match: 25.5%)
# [297/500] KIC 5039053 (catalog period: 401.204d)... Not verified (best match: 97.9%)
# [298/500] KIC 5172274 (catalog period: 6.127d)... VERIFIED ✓ (match: 2.6% via 1.5x harmonic, dist: 0.076 AU, HZ: False)
# [299/500] KIC 10295951 (catalog period: 6.811d)... VERIFIED ✓ (match: 9.0% via 0.5x harmonic, dist: 0.080 AU, HZ: False)
# [300/500] KIC 9072639 (catalog period: 1.183d)... VERIFIED ✓ (match: 18.3% via 1.5x harmonic, dist: 0.024 AU, HZ: False)
# [301/500] KIC 7100673 (catalog period: 7.235d)... Not verified (best match: 33.7%)
# [302/500] KIC 7778427 (catalog period: 5.383d)... Not verified (best match: 72.1%)
# [303/500] KIC 9084569 (catalog period: 395.131d)... Not verified (best match: 95.2%)
# [304/500] KIC 7137213 (catalog period: 28.643d)... Not verified (best match: 85.3%)
# [305/500] KIC 2443393 (catalog period: 73.711d)... Not verified (best match: 21.6%)
# [306/500] KIC 5036052 (catalog period: 143.164d)... Not verified (best match: 86.6%)
# [307/500] KIC 8394475 (catalog period: 3.640d)... VERIFIED ✓ (match: 5.8% via fundamental, dist: 0.046 AU, HZ: False)
# [308/500] KIC 9541295 (catalog period: 0.537d)... VERIFIED ✓ (match: 5.6% via 3.0x harmonic, dist: 0.014 AU, HZ: False)
# [309/500] KIC 4253860 (catalog period: 155.045d)... Not verified (best match: 99.0%)
# [310/500] KIC 8288404 (catalog period: 519.798d)... Not verified (best match: 97.5%)
# [311/500] KIC 10028352 (catalog period: 1.387d)... VERIFIED ✓ (match: 15.9% via 1.5x harmonic, dist: 0.029 AU, HZ: False)
# [312/500] KIC 11182706 (catalog period: 384.377d)... Not verified (best match: 95.5%)
# [313/500] KIC 9943009 (catalog period: 2.438d)... VERIFIED ✓ (match: 1.5% via 2.0x harmonic, dist: 0.037 AU, HZ: False)
# [314/500] KIC 3965201 (catalog period: 44.114d)... Not verified (best match: 91.4%)
# [315/500] KIC 1723078 (catalog period: 330.025d)... Not verified (best match: 98.4%)
# [316/500] KIC 9936080 (catalog period: 19.565d)... VERIFIED ✓ (match: 4.5% via 0.5x harmonic, dist: 0.151 AU, HZ: False)
# [317/500] KIC 9716028 (catalog period: 17.373d)... Not verified (best match: 43.8%)
# [318/500] KIC 5039228 (catalog period: 7.797d)... VERIFIED ✓ (match: 4.5% via 2.0x harmonic, dist: 0.086 AU, HZ: False)
# [319/500] KIC 4840327 (catalog period: 26.737d)... Not verified (best match: 37.2%)
# [320/500] KIC 6451368 (catalog period: 5.336d)... Not verified (best match: 60.6%)
# [321/500] KIC 7917068 (catalog period: 416.950d)... Not verified (best match: 96.0%)
# [322/500] KIC 4548098 (catalog period: 5.216d)... VERIFIED ✓ (match: 9.3% via 0.5x harmonic, dist: 0.063 AU, HZ: False)
# [323/500] KIC 11199725 (catalog period: 1.033d)... VERIFIED ✓ (match: 8.0% via 2.0x harmonic, dist: 0.029 AU, HZ: False)
# [324/500] KIC 9079671 (catalog period: 535.152d)... Not verified (best match: 96.8%)
# [325/500] KIC 4914221 (catalog period: 111.187d)... Not verified (best match: 91.2%)
# [326/500] KIC 12506986 (catalog period: 419.934d)... Not verified (best match: 97.8%)
# [327/500] KIC 8684730 (catalog period: 46.151d)... Not verified (best match: 67.1%)
# [328/500] KIC 12785320 (catalog period: 57.384d)... Not verified (best match: 65.8%)
# [329/500] KIC 7515336 (catalog period: 5.657d)... Not verified (best match: 80.5%)
# [330/500] KIC 11959893 (catalog period: 40.728d)... Not verified (best match: 84.8%)
# [331/500] KIC 4472818 (catalog period: 15.357d)... VERIFIED ✓ (match: 3.9% via 0.5x harmonic, dist: 0.122 AU, HZ: False)
# [332/500] KIC 4255422 (catalog period: 165.406d)... Not verified (best match: 93.6%)
# [333/500] KIC 9243795 (catalog period: 14.443d)... VERIFIED ✓ (match: 2.9% via 0.5x harmonic, dist: 0.133 AU, HZ: False)
# [334/500] KIC 11401253 (catalog period: 4.965d)... VERIFIED ✓ (match: 14.8% via fundamental, dist: 0.057 AU, HZ: False)
# [335/500] KIC 4770174 (catalog period: 6.096d)... VERIFIED ✓ (match: 12.2% via fundamental, dist: 0.072 AU, HZ: False)
# [336/500] KIC 6366559 (catalog period: 55.758d)... Not verified (best match: 97.5%)
# [337/500] KIC 4572728 (catalog period: 309.192d)... Not verified (best match: 94.8%)
# [338/500] KIC 2852810 (catalog period: 126.506d)... Not verified (best match: 91.3%)
# [339/500] KIC 11305417 (catalog period: 198.781d)... Not verified (best match: 96.3%)
# [340/500] KIC 2301068 (catalog period: 8.610d)... Not verified (best match: 83.7%)
# [341/500] KIC 10351947 (catalog period: 260.446d)... Not verified (best match: 96.9%)
# [342/500] KIC 4739229 (catalog period: 571.281d)... Not verified (best match: 99.7%)
# [343/500] KIC 7051984 (catalog period: 0.339d)... VERIFIED ✓ (match: 16.4% via 3.0x harmonic, dist: 0.010 AU, HZ: False)
# [344/500] KIC 5179609 (catalog period: 43.931d)... Not verified (best match: 92.7%)
# [345/500] KIC 8454250 (catalog period: 5.083d)... VERIFIED ✓ (match: 5.1% via 2.0x harmonic, dist: 0.058 AU, HZ: False)
# [346/500] KIC 9654875 (catalog period: 1.341d)... VERIFIED ✓ (match: 14.3% via 3.0x harmonic, dist: 0.029 AU, HZ: False)
# [347/500] KIC 3663850 (catalog period: 141.400d)... Not verified (best match: 93.5%)
# [348/500] KIC 4285087 (catalog period: 2.243d)... VERIFIED ✓ (match: 3.0% via 2.0x harmonic, dist: 0.033 AU, HZ: False)
# [349/500] KIC 9836563 (catalog period: 4.727d)... VERIFIED ✓ (match: 3.4% via 1.5x harmonic, dist: 0.057 AU, HZ: False)
# [350/500] KIC 9579641 (catalog period: 3.436d)... VERIFIED ✓ (match: 8.7% via 1.5x harmonic, dist: 0.044 AU, HZ: False)
# [351/500] KIC 11350634 (catalog period: 278.389d)... Not verified (best match: 93.7%)
# [352/500] KIC 7837526 (catalog period: 28.297d)... Not verified (best match: 93.6%)
# [353/500] KIC 5444276 (catalog period: 0.709d)... Not verified (best match: 99.8%)
# [354/500] KIC 9886361 (catalog period: 24.561d)... Not verified (best match: 31.3%)
# [355/500] KIC 11860294 (catalog period: 545.206d)... Not verified (best match: 99.1%)
# [356/500] KIC 10019399 (catalog period: 11.806d)... Not verified (best match: 30.5%)
# [357/500] KIC 9491832 (catalog period: 49.565d)... Not verified (best match: 31.4%)
# [358/500] KIC 8227464 (catalog period: 4.259d)... VERIFIED ✓ (match: 9.6% via 1.5x harmonic, dist: 0.051 AU, HZ: False)
# [359/500] KIC 5857656 (catalog period: 313.051d)... Not verified (best match: 98.9%)
# [360/500] KIC 6965293 (catalog period: 5.078d)... VERIFIED ✓ (match: 2.4% via 0.5x harmonic, dist: 0.058 AU, HZ: False)
# [361/500] KIC 6048024 (catalog period: 62.816d)... Not verified (best match: 71.0%)
# [362/500] KIC 9521317 (catalog period: 188.881d)... Not verified (best match: 96.0%)
# [363/500] KIC 8264402 (catalog period: 215.960d)... Not verified (best match: 93.0%)
# [364/500] KIC 7106173 (catalog period: 6.232d)... VERIFIED ✓ (match: 3.3% via 2.0x harmonic, dist: 0.069 AU, HZ: False)
# [365/500] KIC 8581240 (catalog period: 10.768d)... VERIFIED ✓ (match: 9.7% via 2.0x harmonic, dist: 0.094 AU, HZ: False)
# [366/500] KIC 9283156 (catalog period: 5.224d)... VERIFIED ✓ (match: 11.9% via 0.5x harmonic, dist: 0.056 AU, HZ: False)
# [367/500] KIC 4912589 (catalog period: 34.188d)... Not verified (best match: 76.0%)
# [368/500] KIC 4037428 (catalog period: 4.265d)... VERIFIED ✓ (match: 0.8% via 0.5x harmonic, dist: 0.049 AU, HZ: False)
# [369/500] KIC 9652166 (catalog period: 0.647d)... VERIFIED ✓ (match: 8.3% via fundamental, dist: 0.017 AU, HZ: False)
# [370/500] KIC 8121310 (catalog period: 11.506d)... VERIFIED ✓ (match: 3.5% via fundamental, dist: 0.110 AU, HZ: False)
# [371/500] KIC 7198587 (catalog period: 651.358d)... Not verified (best match: 99.0%)
# [372/500] KIC 7891294 (catalog period: 3.077d)... VERIFIED ✓ (match: 18.6% via fundamental, dist: 0.043 AU, HZ: False)
# [373/500] KIC 8094120 (catalog period: 5.680d)... Not verified (best match: 38.4%)
# [374/500] KIC 2309719 (catalog period: 54.356d)... Not verified (best match: 79.0%)
# [375/500] KIC 12301181 (catalog period: 2.186d)... VERIFIED ✓ (match: 0.9% via 1.5x harmonic, dist: 0.031 AU, HZ: False)
# [376/500] KIC 4639868 (catalog period: 53.101d)... Not verified (best match: 96.2%)
# [377/500] KIC 8806985 (catalog period: 7.537d)... VERIFIED ✓ (match: 3.5% via 0.5x harmonic, dist: 0.080 AU, HZ: False)
# [378/500] KIC 9899181 (catalog period: 18.940d)... Not verified (best match: 72.3%)
# [379/500] KIC 3634169 (catalog period: 2.959d)... VERIFIED ✓ (match: 17.2% via fundamental, dist: 0.040 AU, HZ: False)
# [380/500] KIC 4255944 (catalog period: 228.654d)... Not verified (best match: 95.9%)
# [381/500] KIC 4164922 (catalog period: 18.257d)... Not verified (best match: 33.7%)
# [382/500] KIC 11656928 (catalog period: 78.867d)... Not verified (best match: 80.5%)
# [383/500] KIC 9397900 (catalog period: 10.511d)... VERIFIED ✓ (match: 2.0% via fundamental, dist: 0.100 AU, HZ: False)
# [384/500] KIC 8719419 (catalog period: 12.625d)... Not verified (best match: 73.7%)
# [385/500] KIC 5946568 (catalog period: 3.564d)... VERIFIED ✓ (match: 13.2% via 1.5x harmonic, dist: 0.044 AU, HZ: False)
# [386/500] KIC 6975129 (catalog period: 37.840d)... Not verified (best match: 87.3%)
# [387/500] KIC 9044060 (catalog period: 476.920d)... Not verified (best match: 99.0%)
# [388/500] KIC 4813793 (catalog period: 6.702d)... Not verified (best match: 70.2%)
# [389/500] KIC 5809372 (catalog period: 34.651d)... Not verified (best match: 90.8%)
# [390/500] KIC 9489524 (catalog period: 4.789d)... Not verified (best match: 31.6%)
# [391/500] KIC 8505215 (catalog period: 579.931d)... Not verified (best match: 88.8%)
# [392/500] KIC 9880467 (catalog period: 8.973d)... VERIFIED ✓ (match: 6.4% via 2.0x harmonic, dist: 0.099 AU, HZ: False)
# [393/500] KIC 9533489 (catalog period: 197.146d)... Not verified (best match: 99.5%)
# [394/500] KIC 7416646 (catalog period: 365.740d)... Not verified (best match: 96.5%)
# [395/500] KIC 9289704 (catalog period: 34.136d)... Not verified (best match: 43.8%)
# [396/500] KIC 4758350 (catalog period: 91.650d)... Not verified (best match: 97.6%)
# [397/500] KIC 7125794 (catalog period: 126.586d)... Not verified (best match: 94.8%)
# [398/500] KIC 7199060 (catalog period: 64.184d)... Not verified (best match: 92.8%)
# [399/500] KIC 11651240 (catalog period: 93.006d)... Not verified (best match: 91.4%)
# [400/500] KIC 10026544 (catalog period: 176.331d)... Not verified (best match: 99.0%)
# [401/500] KIC 6364582 (catalog period: 486.127d)... Not verified (best match: 94.3%)
# [402/500] KIC 4071638 (catalog period: 349.588d)... Not verified (best match: 84.9%)
# [403/500] KIC 9466042 (catalog period: 9.274d)... Not verified (best match: 62.3%)
# [404/500] KIC 11071200 (catalog period: 44.565d)... Not verified (best match: 92.4%)
# [405/500] KIC 8626325 (catalog period: 16.449d)... VERIFIED ✓ (match: 16.3% via 0.5x harmonic, dist: 0.144 AU, HZ: False)
# [406/500] KIC 7050060 (catalog period: 22.045d)... VERIFIED ✓ (match: 0.7% via fundamental, dist: 0.151 AU, HZ: False)
# [407/500] KIC 5385304 (catalog period: 78.733d)... Not verified (best match: 77.4%)
# [408/500] KIC 4164511 (catalog period: 40.988d)... Not verified (best match: 80.5%)
# [409/500] KIC 9459162 (catalog period: 3.799d)... VERIFIED ✓ (match: 9.2% via fundamental, dist: 0.053 AU, HZ: False)
# [410/500] KIC 8628761 (catalog period: 6.304d)... Not verified (best match: 63.5%)
# [411/500] KIC 10850327 (catalog period: 440.161d)... Not verified (best match: 97.5%)
# [412/500] KIC 7833305 (catalog period: 8.312d)... VERIFIED ✓ (match: 9.8% via 0.5x harmonic, dist: 0.073 AU, HZ: False)
# [413/500] KIC 3852872 (catalog period: 80.770d)... Not verified (best match: 91.8%)
# [414/500] KIC 4915582 (catalog period: 436.188d)... Not verified (best match: 98.9%)
# [415/500] KIC 11615521 (catalog period: 366.685d)... Not verified (best match: 97.8%)
# [416/500] KIC 7661893 (catalog period: 2.494d)... VERIFIED ✓ (match: 10.9% via 1.5x harmonic, dist: 0.036 AU, HZ: False)
# [417/500] KIC 4366923 (catalog period: 646.288d)... Not verified (best match: 99.5%)
# [418/500] KIC 9340411 (catalog period: 5.158d)... VERIFIED ✓ (match: 18.6% via fundamental, dist: 0.064 AU, HZ: False)
# [419/500] KIC 3229028 (catalog period: 117.685d)... Not verified (best match: 90.3%)
# [420/500] KIC 6594945 (catalog period: 188.966d)... Not verified (best match: 99.4%)
# [421/500] KIC 10290666 (catalog period: 6.867d)... Not verified (best match: 20.6%)
# [422/500] KIC 5471489 (catalog period: 39.282d)... VERIFIED ✓ (match: 5.3% via 0.5x harmonic, dist: 0.232 AU, HZ: False)
# [423/500] KIC 8074328 (catalog period: 4.268d)... Not verified (best match: 27.4%)
# [424/500] KIC 4252671 (catalog period: 23.267d)... Not verified (best match: 91.7%)
# [425/500] KIC 5859725 (catalog period: 18.982d)... Not verified (best match: 94.7%)
# [426/500] KIC 7625143 (catalog period: 58.503d)... Not verified (best match: 38.5%)
# [427/500] KIC 6767227 (catalog period: 4.082d)... VERIFIED ✓ (match: 7.8% via 0.5x harmonic, dist: 0.051 AU, HZ: False)
# [428/500] KIC 5211199 (catalog period: 6.682d)... VERIFIED ✓ (match: 19.9% via fundamental, dist: 0.076 AU, HZ: False)
# [429/500] KIC 8625408 (catalog period: 279.013d)... Not verified (best match: 96.5%)
# [430/500] KIC 8423903 (catalog period: 12.494d)... Not verified (best match: 91.2%)
# [431/500] KIC 10232123 (catalog period: 1.344d)... VERIFIED ✓ (match: 0.5% via fundamental, dist: 0.026 AU, HZ: False)
# [432/500] KIC 10616571 (catalog period: 23.673d)... VERIFIED ✓ (match: 15.3% via fundamental, dist: 0.169 AU, HZ: False)
# [433/500] KIC 9391817 (catalog period: 140.885d)... Not verified (best match: 98.6%)
# [434/500] KIC 11519134 (catalog period: 58.585d)... Not verified (best match: 80.5%)
# [435/500] KIC 7134626 (catalog period: 2.524d)... VERIFIED ✓ (match: 6.9% via fundamental, dist: 0.039 AU, HZ: False)
# [436/500] KIC 7918652 (catalog period: 11.455d)... Not verified (best match: 87.8%)
# [437/500] KIC 12254688 (catalog period: 62.683d)... Not verified (best match: 71.0%)
# [438/500] KIC 11341266 (catalog period: 284.872d)... Not verified (best match: 96.6%)
# [439/500] KIC 8702537 (catalog period: 7.475d)... Not verified (best match: 84.0%)
# [440/500] KIC 10228942 (catalog period: 21.025d)... Not verified (best match: 78.4%)
# [441/500] KIC 12367464 (catalog period: 1.853d)... VERIFIED ✓ (match: 0.2% via fundamental, dist: 0.031 AU, HZ: False)
# [442/500] KIC 4484179 (catalog period: 385.292d)... Not verified (best match: 99.4%)
# [443/500] KIC 11614808 (catalog period: 175.453d)... Not verified (best match: 90.5%)
# [444/500] KIC 9111849 (catalog period: 63.074d)... Not verified (best match: 97.2%)
# [445/500] KIC 7622486 (catalog period: 40.247d)... Not verified (best match: 88.6%)
# [446/500] KIC 6067545 (catalog period: 550.860d)... Not verified (best match: 97.2%)
# [447/500] KIC 8105398 (catalog period: 5.683d)... Not verified (best match: 47.2%)
# [448/500] KIC 5347784 (catalog period: 9.584d)... VERIFIED ✓ (match: 17.6% via fundamental, dist: 0.095 AU, HZ: False)
# [449/500] KIC 8773015 (catalog period: 6.319d)... Not verified (best match: 44.6%)
# [450/500] KIC 8233326 (catalog period: 3.741d)... Not verified (best match: 35.9%)
# [451/500] KIC 3866536 (catalog period: 7.652d)... VERIFIED ✓ (match: 0.7% via 0.5x harmonic, dist: 0.076 AU, HZ: False)
# [452/500] KIC 5687986 (catalog period: 382.303d)... Not verified (best match: 95.5%)
# [453/500] KIC 8566113 (catalog period: 1.372d)... VERIFIED ✓ (match: 13.0% via fundamental, dist: 0.027 AU, HZ: False)
# [454/500] KIC 8016692 (catalog period: 6.614d)... VERIFIED ✓ (match: 11.9% via fundamental, dist: 0.070 AU, HZ: False)
# [455/500] KIC 5897826 (catalog period: 0.875d)... VERIFIED ✓ (match: 8.6% via fundamental, dist: 0.019 AU, HZ: False)
# [456/500] KIC 3324069 (catalog period: 22.803d)... Not verified (best match: 22.0%)
# [457/500] KIC 11453930 (catalog period: 355.847d)... Not verified (best match: 96.3%)
# [458/500] KIC 11825996 (catalog period: 16.916d)... Not verified (best match: 94.1%)
# [459/500] KIC 10928043 (catalog period: 6.846d)... VERIFIED ✓ (match: 14.3% via 1.5x harmonic, dist: 0.074 AU, HZ: False)
# [460/500] KIC 10352333 (catalog period: 1.571d)... VERIFIED ✓ (match: 5.1% via 3.0x harmonic, dist: 0.025 AU, HZ: False)
# [461/500] KIC 7695445 (catalog period: 1.743d)... Not verified (best match: 22.6%)
# [462/500] KIC 7051180 (catalog period: 1.951d)... VERIFIED ✓ (match: 15.3% via fundamental, dist: 0.033 AU, HZ: False)
# [463/500] KIC 12105086 (catalog period: 73.909d)... Not verified (best match: 77.8%)
# [464/500] KIC 8559796 (catalog period: 0.619d)... VERIFIED ✓ (match: 7.2% via 2.0x harmonic, dist: 0.016 AU, HZ: False)
# [465/500] KIC 7950158 (catalog period: 529.392d)... Not verified (best match: 96.8%)
# [466/500] KIC 6523351 (catalog period: 6.067d)... VERIFIED ✓ (match: 14.6% via fundamental, dist: 0.064 AU, HZ: False)
# [467/500] KIC 6277594 (catalog period: 3.661d)... VERIFIED ✓ (match: 7.8% via 2.0x harmonic, dist: 0.047 AU, HZ: False)
# [468/500] KIC 11967788 (catalog period: 7.235d)... Not verified (best match: 22.6%)
# [469/500] KIC 3955444 (catalog period: 62.312d)... Not verified (best match: 98.1%)
# [470/500] KIC 9893468 (catalog period: 201.325d)... Not verified (best match: 95.9%)
# [471/500] KIC 7900450 (catalog period: 25.481d)... VERIFIED ✓ (match: 17.6% via 0.5x harmonic, dist: 0.172 AU, HZ: False)
# [472/500] KIC 6146838 (catalog period: 27.467d)... Not verified (best match: 93.5%)
# [473/500] KIC 10199984 (catalog period: 198.600d)... Not verified (best match: 99.5%)
# [474/500] KIC 12300524 (catalog period: 32.034d)... Not verified (best match: 55.7%)
# [475/500] KIC 1429589 (catalog period: 38.169d)... VERIFIED ✓ (match: 7.4% via 0.5x harmonic, dist: 0.224 AU, HZ: False)
# [476/500] KIC 5898983 (catalog period: 40.145d)... Not verified (best match: 68.1%)
# [477/500] KIC 8644365 (catalog period: 10.548d)... Not verified (best match: 58.3%)
# [478/500] KIC 6058816 (catalog period: 4.748d)... VERIFIED ✓ (match: 5.2% via 0.5x harmonic, dist: 0.055 AU, HZ: False)
# [479/500] KIC 4141593 (catalog period: 64.740d)... Not verified (best match: 91.3%)
# [480/500] KIC 5596440 (catalog period: 10.475d)... Not verified (best match: 71.4%)
# [481/500] KIC 7345248 (catalog period: 5.665d)... Not verified (best match: 73.5%)
# [482/500] KIC 10794974 (catalog period: 66.643d)... Not verified (best match: 96.1%)
# [483/500] KIC 8564976 (catalog period: 152.828d)... Not verified (best match: 86.5%)
# [484/500] KIC 12647757 (catalog period: 490.639d)... Not verified (best match: 87.4%)
# [485/500] KIC 5096053 (catalog period: 1.718d)... VERIFIED ✓ (match: 6.7% via 1.5x harmonic, dist: 0.031 AU, HZ: False)
# [486/500] KIC 4737848 (catalog period: 56.002d)... Not verified (best match: 92.1%)
# [487/500] KIC 5856571 (catalog period: 80.410d)... Not verified (best match: 83.3%)
# [488/500] KIC 11182260 (catalog period: 1.292d)... VERIFIED ✓ (match: 0.6% via fundamental, dist: 0.020 AU, HZ: False)
# [489/500] KIC 6527078 (catalog period: 10.431d)... Not verified (best match: 56.9%)
# [490/500] KIC 10319385 (catalog period: 0.689d)... VERIFIED ✓ (match: 1.6% via fundamental, dist: 0.016 AU, HZ: False)
# [491/500] KIC 4058169 (catalog period: 282.536d)... Not verified (best match: 98.5%)
# [492/500] KIC 5090690 (catalog period: 12.012d)... Not verified (best match: 68.4%)
# [493/500] KIC 8590780 (catalog period: 4.327d)... VERIFIED ✓ (match: 11.0% via fundamental, dist: 0.052 AU, HZ: False)
# [494/500] KIC 10646620 (catalog period: 2.413d)... VERIFIED ✓ (match: 4.7% via fundamental, dist: 0.037 AU, HZ: False)
# [495/500] KIC 4349442 (catalog period: 4.539d)... VERIFIED ✓ (match: 13.0% via 2.0x harmonic, dist: 0.049 AU, HZ: False)
# [496/500] KIC 9466486 (catalog period: 557.929d)... Not verified (best match: 99.2%)
# [497/500] KIC 8890924 (catalog period: 4.441d)... Not verified (best match: 73.0%)
# [498/500] KIC 6792908 (catalog period: 10.778d)... Not verified (best match: 76.8%)
# [499/500] KIC 9117416 (catalog period: 7.644d)... VERIFIED ✓ (match: 15.0% via 1.5x harmonic, dist: 0.082 AU, HZ: False)
# [500/500] KIC 7673192 (catalog period: 16.534d)... VERIFIED ✓ (match: 9.8% via fundamental, dist: 0.133 AU, HZ: False)
#
# ============================================================
# PIPELINE COMPLETE
# ============================================================
# Verified candidates:    177
# Not verified:           323
# Failed (no data):       0
# Verification rate:      35.4%

# %%
print("SELECTION BIAS — EXTENDED ANALYSIS")
print("=" * 60)

# Temperature distribution of verified stars
print("\nStellar temperature breakdown:")
bins = [0, 4000, 5000, 6000, 7000, 99999]
labels = ['<4000K (M dwarf)', '4000-5000K (K dwarf)', 
          '5000-6000K (G dwarf)', '6000-7000K (F dwarf)', '>7000K (A star)']
results_df['star_type'] = pd.cut(
    results_df['stellar_temp (K)'], 
    bins=bins, labels=labels
)
print(results_df['star_type'].value_counts().to_string())

# How far each planet is from its HZ
results_df['au_below_hz_inner'] = (
    results_df['hz_inner (AU)'] - results_df['orbital_dist (AU)']
).round(4)

print(f"\nAll 177 verified planets orbit INSIDE their star's HZ inner edge")
print(f"Mean distance below HZ inner edge: "
      f"{results_df['au_below_hz_inner'].mean():.3f} AU")
print(f"Closest planet to HZ inner edge: "
      f"{results_df['au_below_hz_inner'].min():.3f} AU short")
print(f"\nConclusion: Zero HZ candidates reflects both Kepler's")
print(f"detection bias toward short-period planets AND a sample")
print(f"dominated by hot luminous stars with distant habitable zones.")
# Out:
# SELECTION BIAS — EXTENDED ANALYSIS
# ============================================================
#
# Stellar temperature breakdown:
# star_type
# 6000-7000K (F dwarf)    78
# 5000-6000K (G dwarf)    60
# >7000K (A star)         22
# 4000-5000K (K dwarf)    16
# <4000K (M dwarf)         1
#
# All 177 verified planets orbit INSIDE their star's HZ inner edge
# Mean distance below HZ inner edge: 2.388 AU
# Closest planet to HZ inner edge: 0.036 AU short
#
# Conclusion: Zero HZ candidates reflects both Kepler's
# detection bias toward short-period planets AND a sample
# dominated by hot luminous stars with distant habitable zones.

# %%
print("\nVERIFIED CANDIDATES SUMMARY")
print("=" * 60)

if len(results_df) > 0:
    hz_df = results_df[results_df['in_habitable_zone'] == True]
    
    print(f"Total verified:         {len(results_df)}")
    print(f"In habitable zone:      {len(hz_df)}")
    print(f"\nPlanet type breakdown:")
    print(results_df['planet_type'].value_counts().to_string())
    
    print(f"\nHABITABLE ZONE CANDIDATES:")
    print("=" * 60)
    if len(hz_df) > 0:
        print(hz_df[['kepoi_name', 'catalog_period (days)',
                      'detected_period (days)', 'period_match (%)',
                      'orbital_dist (AU)', 'planet_radius (R_earth)',
                      'planet_type']].to_string())
    else:
        print("No habitable zone candidates in this sample")
else:
    print("No verified candidates — check pipeline")
# Out:
# VERIFIED CANDIDATES SUMMARY
# ============================================================
# Total verified:         177
# In habitable zone:      0
#
# Planet type breakdown:
# planet_type
# Rocky            64
# Super-Jupiter    60
# Super-Earth      29
# Mini-Neptune     14
# Gas Giant        10
#
# HABITABLE ZONE CANDIDATES:
# ============================================================
# No habitable zone candidates in this sample

# %%
# ── SECTION 7: BEST CANDIDATE VISUALIZATION ──────────────────

# Find best candidate — lowest period match %
best = results_df.nsmallest(1, 'period_match (%)').iloc[0]

print(f"Best candidate selected: {best['kepoi_name']}")
print(f"  KIC ID:              {best['kepid']}")
print(f"  Period:              {best['catalog_period (days)']:.4f} days")
print(f"  Period match:        {best['period_match (%)']:.2f}%")
print(f"  Orbital distance:    {best['orbital_dist (AU)']:.4f} AU")
print(f"  Planet type:         {best['planet_type']}")
print(f"  Stellar temp:        {best['stellar_temp (K)']:.0f} K")

# Download fresh light curve for this star
print(f"\nDownloading light curve for visualization...")
search = lk.search_lightcurve(
    f"KIC {best['kepid']}",
    mission="Kepler",
    cadence="long"
)
lc = search[0].download()
lc = lc.remove_nans().remove_outliers(sigma=3).normalize()

# Fold on the catalog period
period = best['catalog_period (days)']
lc_folded = lc.fold(period=period)
lc_binned = lc_folded.bin(time_bin_size=0.005)

# ── PLOT ─────────────────────────────────────────────────────
fig, axes = plt.subplots(2, 1, figsize=(12, 10))
fig.suptitle(
    f"Best Verified Candidate: {best['kepoi_name']} (KIC {best['kepid']})\n"
    f"Period: {period:.4f} days | Match: {best['period_match (%)']:.2f}% | "
    f"Type: {best['planet_type']}",
    fontsize=13, fontweight='bold'
)

# ── TOP PANEL: Raw light curve ────────────────────────────────
axes[0].scatter(
    lc.time.value, lc.flux.value,
    s=1, alpha=0.4, color='steelblue'
)
axes[0].set_xlabel('Time (BKJD days)', fontsize=11)
axes[0].set_ylabel('Normalized Flux', fontsize=11)
axes[0].set_title('Raw Light Curve', fontsize=11)

t0 = lc.time.value.min()
t_end = lc.time.value.max()
transit_times = np.arange(t0, t_end, period)
for t in transit_times:
    axes[0].axvline(t, color='red', alpha=0.3, linewidth=0.8)

# ── BOTTOM PANEL: Folded + binned with highlighted dip ────────
axes[1].scatter(
    lc_folded.time.value, lc_folded.flux.value,
    s=1, alpha=0.2, color='steelblue', label='Individual measurements'
)
axes[1].plot(
    lc_binned.time.value, lc_binned.flux.value,
    color='navy', linewidth=2, label='Binned average', zorder=3
)

# Find the transit dip automatically
flux_vals = lc_binned.flux.value
time_vals = lc_binned.time.value
dip_idx = np.argmin(flux_vals)
dip_time = time_vals[dip_idx]
dip_flux = flux_vals[dip_idx]

# Highlight the dip region
dip_width = period * 0.05
axes[1].axvspan(
    dip_time - dip_width,
    dip_time + dip_width,
    alpha=0.25, color='red', label='Transit zone'
)

# Annotate the dip
axes[1].annotate(
    f'Transit dip\nFlux = {dip_flux:.5f}',
    xy=(dip_time, dip_flux),
    xytext=(dip_time + period * 0.1, dip_flux - 0.0005),
    fontsize=9,
    arrowprops=dict(arrowstyle='->', color='red'),
    color='red'
)

# Baseline reference line
baseline = np.median(flux_vals)
axes[1].axhline(
    baseline, color='gray', linestyle='--',
    linewidth=1, alpha=0.7, label=f'Baseline flux = {baseline:.5f}'
)

# Transit depth annotation
depth = baseline - dip_flux
axes[1].annotate(
    '',
    xy=(dip_time - dip_width * 1.5, dip_flux),
    xytext=(dip_time - dip_width * 1.5, baseline),
    arrowprops=dict(arrowstyle='<->', color='darkred', lw=1.5)
)
axes[1].text(
    dip_time - dip_width * 3, (baseline + dip_flux) / 2,
    f'Depth\n{depth:.5f}',
    fontsize=8, color='darkred', ha='center'
)

axes[1].set_xlabel('Phase (days)', fontsize=11)
axes[1].set_ylabel('Normalized Flux', fontsize=11)
axes[1].set_title('Folded Light Curve — Transit Dip Highlighted', fontsize=11)
axes[1].legend(fontsize=9, loc='upper right')

plt.tight_layout()
plt.savefig(
    f'./outputs/v4_best_candidate_{best["kepoi_name"].replace(".", "_")}.png',
    dpi=150, bbox_inches='tight'
)
plt.show()
print(f"\nPlot saved to outputs/")
# Out:
# Best candidate selected: K05145.01
#   KIC ID:              5263802
#   Period:              3.3502 days
#   Period match:        0.01%
#   Orbital distance:    0.0512 AU
#   Planet type:         Super-Jupiter
#   Stellar temp:        6915 K
#
# Downloading light curve for visualization...
# Plot saved to outputs/

# %%
results_df.to_csv('./outputs/v4_verified_candidates.csv', index=False)
unverified_df.to_csv('./outputs/v4_unverified.csv', index=False)
failed_df.to_csv('./outputs/v4_failed.csv', index=False)

print("Saved:")
print("  outputs/v4_verified_candidates.csv")
print("  outputs/v4_unverified.csv")
print("  outputs/v4_failed.csv")
